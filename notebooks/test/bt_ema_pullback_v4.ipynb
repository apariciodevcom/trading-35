# %%
# bt_ema_pullback_v4.ipynb

import sys
sys.path.append("D:/trading")  # o el path donde está tu carpeta my_modules
# ✅ CELDA 1: Preparación del entorno
import pandas as pd
import numpy as np
import os
from tqdm import tqdm
from my_modules.estrategias.v4 import ema_pullback_v4

# Cargar históricos locales
ruta_historicos = "D:/trading/data/historic"
historicos = {}
for archivo in os.listdir(ruta_historicos):
    if archivo.endswith(".parquet"):
        ticker = archivo.replace(".parquet", "")
        df = pd.read_parquet(os.path.join(ruta_historicos, archivo))
        if len(df) >= 25:
            historicos[ticker] = df

print(f"Históricos cargados: {len(historicos)} símbolos")
# Out:
# Históricos cargados: 48 símbolos

# %%
# ✅ CELDA 2: Loop de generación y simulación de señales
resultados = []

for ticker, df in tqdm(historicos.items()):
    df_signals = ema_pullback_v4.generar_senales(
        df,
        usar_filtro_volatilidad=True,
        atr_threshold=0.010,
        rebote_required=True,
        tendencia_required=True,
        debug=False
    )

    df_signals = df_signals[df_signals["signal"] != "hold"]
    if df_signals.empty:
        continue

    df_precio = df.copy()
    df_precio["fecha"] = pd.to_datetime(df_precio["fecha"])
    df_signals["fecha"] = pd.to_datetime(df_signals["fecha"])
    df_merged = df_precio.merge(df_signals, on="fecha")

    for _, row in df_merged.iterrows():
        fecha_entrada = row["fecha"]
        precio_entrada = row["close"]
        df_rango = df_precio[(df_precio["fecha"] > fecha_entrada) & (df_precio["fecha"] <= fecha_entrada + pd.Timedelta(days=7))]
        if df_rango.empty:
            continue

        tipo_salida = "TIMEOUT"
        fila_salida = df_rango.iloc[-1]

        for _, f in df_rango.iterrows():
            if row["signal"] == "buy":
                if f["high"] >= precio_entrada * 1.05:
                    tipo_salida = "TP"; fila_salida = f; break
                if f["low"] <= precio_entrada * 0.97:
                    tipo_salida = "SL"; fila_salida = f; break
            elif row["signal"] == "sell":
                if f["low"] <= precio_entrada * 0.95:
                    tipo_salida = "TP"; fila_salida = f; break
                if f["high"] >= precio_entrada * 1.03:
                    tipo_salida = "SL"; fila_salida = f; break

        precio_salida = fila_salida["close"]
        dias = (fila_salida["fecha"] - fecha_entrada).days
        resultado = precio_salida - precio_entrada if row["signal"] == "buy" else precio_entrada - precio_salida
        ret_pct = (precio_salida / precio_entrada - 1) * (1 if row["signal"] == "buy" else -1)
        log_ret = np.log(precio_salida / precio_entrada) * (1 if row["signal"] == "buy" else -1)

        resultados.append({
            "ticker": ticker,
            "fecha_entrada": fecha_entrada,
            "fecha_salida": fila_salida["fecha"],
            "dias": dias,
            "precio_entrada": precio_entrada,
            "precio_salida": precio_salida,
            "resultado": resultado,
            "resultado_pct": ret_pct,
            "log_ret": log_ret,
            "f_win": int(resultado > 0),
            "tipo_salida": tipo_salida,
            "estrategia": "ema_pullback_v4",
            "signal": row["signal"]
        })
# Out:
#   0%|                                                                                           | 0/48 [00:00<?, ?it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#   2%|█▋                                                                                 | 1/48 [00:00<00:27,  1.73it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#   4%|███▍                                                                               | 2/48 [00:00<00:20,  2.25it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#   6%|█████▏                                                                             | 3/48 [00:01<00:21,  2.12it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#   8%|██████▉                                                                            | 4/48 [00:01<00:20,  2.16it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  10%|████████▋                                                                          | 5/48 [00:02<00:16,  2.64it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  12%|██████████▍                                                                        | 6/48 [00:02<00:21,  1.98it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  15%|████████████                                                                       | 7/48 [00:03<00:21,  1.88it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  17%|█████████████▊                                                                     | 8/48 [00:03<00:17,  2.28it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  19%|███████████████▌                                                                   | 9/48 [00:04<00:23,  1.68it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  21%|█████████████████                                                                 | 10/48 [00:05<00:27,  1.36it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  23%|██████████████████▊                                                               | 11/48 [00:06<00:29,  1.25it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
# D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  27%|██████████████████████▏                                                           | 13/48 [00:07<00:21,  1.65it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  29%|███████████████████████▉                                                          | 14/48 [00:07<00:18,  1.84it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  31%|█████████████████████████▋                                                        | 15/48 [00:08<00:18,  1.77it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  33%|███████████████████████████▎                                                      | 16/48 [00:09<00:19,  1.60it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  35%|█████████████████████████████                                                     | 17/48 [00:09<00:16,  1.94it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  38%|██████████████████████████████▊                                                   | 18/48 [00:09<00:12,  2.40it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  40%|████████████████████████████████▍                                                 | 19/48 [00:09<00:10,  2.89it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  42%|██████████████████████████████████▏                                               | 20/48 [00:09<00:07,  3.59it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
# D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  46%|█████████████████████████████████████▌                                            | 22/48 [00:10<00:09,  2.87it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  48%|███████████████████████████████████████▎                                          | 23/48 [00:11<00:11,  2.10it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  50%|█████████████████████████████████████████                                         | 24/48 [00:12<00:11,  2.17it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  52%|██████████████████████████████████████████▋                                       | 25/48 [00:12<00:13,  1.76it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
# D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  56%|██████████████████████████████████████████████▏                                   | 27/48 [00:13<00:08,  2.41it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  58%|███████████████████████████████████████████████▊                                  | 28/48 [00:14<00:10,  1.88it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  60%|█████████████████████████████████████████████████▌                                | 29/48 [00:15<00:11,  1.60it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  62%|███████████████████████████████████████████████████▎                              | 30/48 [00:15<00:08,  2.06it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  65%|████████████████████████████████████████████████████▉                             | 31/48 [00:15<00:09,  1.77it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  67%|██████████████████████████████████████████████████████▋                           | 32/48 [00:16<00:08,  1.87it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  69%|████████████████████████████████████████████████████████▍                         | 33/48 [00:17<00:09,  1.65it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  71%|██████████████████████████████████████████████████████████                        | 34/48 [00:18<00:09,  1.44it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
# D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  75%|█████████████████████████████████████████████████████████████▌                    | 36/48 [00:18<00:05,  2.25it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  77%|███████████████████████████████████████████████████████████████▏                  | 37/48 [00:18<00:04,  2.25it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  79%|████████████████████████████████████████████████████████████████▉                 | 38/48 [00:19<00:04,  2.37it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  81%|██████████████████████████████████████████████████████████████████▋               | 39/48 [00:19<00:03,  2.72it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  83%|████████████████████████████████████████████████████████████████████▎             | 40/48 [00:19<00:02,  3.25it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  85%|██████████████████████████████████████████████████████████████████████            | 41/48 [00:20<00:03,  2.20it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  88%|███████████████████████████████████████████████████████████████████████▊          | 42/48 [00:20<00:02,  2.44it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  90%|█████████████████████████████████████████████████████████████████████████▍        | 43/48 [00:21<00:02,  2.10it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  92%|███████████████████████████████████████████████████████████████████████████▏      | 44/48 [00:21<00:01,  2.61it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  94%|████████████████████████████████████████████████████████████████████████████▉     | 45/48 [00:22<00:01,  1.97it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  96%|██████████████████████████████████████████████████████████████████████████████▌   | 46/48 [00:23<00:01,  1.57it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
#  98%|████████████████████████████████████████████████████████████████████████████████▎ | 47/48 [00:24<00:00,  1.31it/s]D:\trading\my_modules\estrategias\v4\ema_pullback_v4.py:90: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["prev_buy"] = pd.Series(df["buy_cond"].shift(1)).fillna(False).astype(bool)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 48/48 [00:25<00:00,  1.91it/s]

# %%
# ✅ CELDA 3: Consolidar y evaluar

import seaborn as sns
import matplotlib.pyplot as plt

df_operaciones = pd.DataFrame(resultados)
print(f"Operaciones simuladas: {len(df_operaciones):,}")

resumen = df_operaciones.groupby("estrategia").agg({
    "resultado": ["sum", "mean", "count"],
    "f_win": "mean",
    "dias": "mean",
    "log_ret": "mean"
})
resumen.columns = ["total_profit", "avg_profit", "n_trades", "winrate", "avg_duracion", "avg_logret"]
resumen["score"] = resumen["avg_profit"] * resumen["winrate"]
resumen = resumen.sort_values("score", ascending=False).round(4)
resumen
# Out:
# Operaciones simuladas: 19,346
#                  total_profit  avg_profit  n_trades  winrate  avg_duracion  \
# estrategia
# ema_pullback_v4      808.4555      0.0418     19346   0.4824          5.68
#
#                  avg_logret   score
# estrategia
# ema_pullback_v4      0.0005  0.0202
