# %%
import json
from pathlib import Path

json_path = Path("config/json/symbols.json")
json_path.parent.mkdir(parents=True, exist_ok=True)

symbolos_test = {
    "simbolos": ["AAPL", "TSLA", "AMD", "NVDA", "MSFT", "SMCI", "XOM"]
}

with open(json_path, "w") as f:
    json.dump(symbolos_test, f, indent=4)

print(f"Archivo de prueba creado en: {json_path.resolve()}")
# Out:
# Archivo de prueba creado en: C:\Users\leant\OneDrive\Documentos\trading\Jupyter\notebooks\test\config\json\symbols.json

# %%
# Conteo de simbolos presentes en el historico y generacion de symbols.json

import json
from pathlib import Path

# === Rutas
BASE_PATH = Path("..").resolve().parent
HISTORIC_DIR = BASE_PATH / "data" / "historic"
CONFIG_PATH = Path("config/json/symbols.json")
CONFIG_PATH.parent.mkdir(parents=True, exist_ok=True)

# === Extraer simbolos desde nombres de archivo
symbolos_detectados = sorted([f.stem.upper() for f in HISTORIC_DIR.glob("*.parquet")])

# === Guardar JSON
with open(CONFIG_PATH, "w") as f:
    json.dump({"simbolos": symbolos_detectados}, f, indent=4)

print(f"Archivo symbols.json generado con {len(symbolos_detectados)} simbolos:")
print(symbolos_detectados)
# Out:
# Archivo symbols.json generado con 673 simbolos:
# ['A', 'AAPL', 'ABBV', 'ABNB', 'ABT', 'ACI', 'ACM', 'ADBE', 'ADI', 'ADM', 'ADP', 'ADSK', 'AEE', 'AEP', 'AFG', 'AFL', 'AFRM', 'AGNCL', 'AGNCM', 'AGNCN', 'AGNCO', 'AGNCP', 'AIG', 'AJG', 'AKAM', 'ALAB', 'ALGN', 'ALL', 'ALLE', 'ALLY', 'ALNY', 'AMAT', 'AMD', 'AME', 'AMGN', 'AMH', 'AMP', 'AMT', 'AMZN', 'ANET', 'ANSS', 'AON', 'APD', 'APG', 'APH', 'APO', 'APOS', 'APP', 'AQNB', 'AR', 'ARCC', 'ARE', 'ARES', 'ARMK', 'ATI', 'ATO', 'ATR', 'AUR', 'AVB', 'AVGO', 'AVY', 'AWK', 'AXON', 'AXP', 'AZO', 'BA', 'BAC', 'BAH', 'BALL', 'BAX', 'BBY', 'BDX', 'BEN', 'BEPC', 'BG', 'BIIB', 'BJ', 'BK', 'BKNG', 'BKR', 'BLDR', 'BLK', 'BMRN', 'BMY', 'BR', 'BRO', 'BROS', 'BSX', 'BSY', 'BTSGU', 'BURL', 'BX', 'BXP', 'C', 'CACI', 'CAG', 'CAH', 'CARR', 'CART', 'CASY', 'CAT', 'CBRE', 'CCI', 'CCK', 'CCL', 'CCZ', 'CDNS', 'CDW', 'CEG', 'CF', 'CFG', 'CG', 'CHD', 'CHRW', 'CHTR', 'CHWY', 'CI', 'CIEN', 'CINF', 'CL', 'CLH', 'CLX', 'CMCSA', 'CME', 'CMG', 'CMI', 'CMS', 'CNA', 'CNC', 'CNM', 'CNP', 'COF', 'COHR', 'COIN', 'COO', 'COP', 'COR', 'COST', 'CPAY', 'CPB', 'CPNG', 'CPRT', 'CPT', 'CQP', 'CRBG', 'CRDO', 'CRM', 'CRS', 'CRWD', 'CRWV', 'CSCO', 'CSGP', 'CSL', 'CSX', 'CTAS', 'CTRA', 'CTSH', 'CTVA', 'CUK', 'CVNA', 'CVS', 'CVX', 'CW', 'D', 'DAL', 'DASH', 'DD', 'DDOG', 'DE', 'DECK', 'DELL', 'DG', 'DGX', 'DHI', 'DHR', 'DIS', 'DKNG', 'DKS', 'DLR', 'DLTR', 'DOC', 'DOCU', 'DOV', 'DOW', 'DPZ', 'DRI', 'DT', 'DTE', 'DTM', 'DUK', 'DUKB', 'DUOL', 'DVA', 'DVN', 'DXCM', 'EA', 'EBAY', 'ECCF', 'ECL', 'ED', 'EFX', 'EHC', 'EIX', 'EL', 'ELS', 'ELV', 'EME', 'EMR', 'ENTG', 'EOG', 'EPAM', 'EPD', 'EQH', 'EQIX', 'EQR', 'EQT', 'ERIE', 'ES', 'ESS', 'ET', 'ETR', 'EVRG', 'EW', 'EWBC', 'EXAS', 'EXC', 'EXE', 'EXEEL', 'EXEEZ', 'EXEL', 'EXPD', 'EXPE', 'EXR', 'F', 'FANG', 'FAST', 'FCNCA', 'FCX', 'FDX', 'FE', 'FFIV', 'FHN', 'FI', 'FICO', 'FIS', 'FITB', 'FITBI', 'FITBO', 'FITBP', 'FIX', 'FNF', 'FOX', 'FOXA', 'FSLR', 'FTAI', 'FTNT', 'FTS', 'FTV', 'FWONA', 'FWONK', 'GAP', 'GD', 'GDDY', 'GE', 'GEHC', 'GEN', 'GEV', 'GFS', 'GGG', 'GILD', 'GIS', 'GLPI', 'GLW', 'GM', 'GME', 'GOOG', 'GOOGL', 'GPC', 'GPN', 'GS', 'GWRE', 'GWW', 'H', 'HAL', 'HBAN', 'HBANL', 'HBANM', 'HBANP', 'HCA', 'HD', 'HEI', 'HES', 'HIG', 'HIMS', 'HLI', 'HLT', 'HOLX', 'HON', 'HOOD', 'HPE', 'HPQ', 'HRL', 'HST', 'HSY', 'HUBB', 'HUBS', 'HUM', 'HWM', 'IBKR', 'IBM', 'ICE', 'IDXX', 'IEX', 'IFF', 'ILMN', 'INCY', 'INSM', 'INTC', 'INTU', 'INVH', 'IONQ', 'IOT', 'IP', 'IQV', 'IR', 'IRM', 'ISRG', 'IT', 'ITT', 'ITW', 'J', 'JBHT', 'JBL', 'JEF', 'JKHY', 'JLL', 'JNJ', 'JNPR', 'JPM', 'K', 'KDP', 'KEY', 'KEYS', 'KHC', 'KIM', 'KKR', 'KKRS', 'KLAC', 'KMB', 'KMI', 'KNSL', 'KO', 'KR', 'KVUE', 'L', 'LAMR', 'LBRDA', 'LBRDK', 'LDOS', 'LECO', 'LEN', 'LH', 'LHX', 'LII', 'LIN', 'LINE', 'LKQ', 'LLY', 'LMT', 'LNG', 'LNT', 'LOGI', 'LOW', 'LPLA', 'LRCX', 'LUV', 'LVS', 'LYV', 'MA', 'MAA', 'MANH', 'MAR', 'MAS', 'MCD', 'MCHP', 'MCHPP', 'MCK', 'MCO', 'MDB', 'MDLZ', 'MDT', 'MET', 'META', 'MKC', 'MKL', 'MLM', 'MMC', 'MMM', 'MNST', 'MO', 'MOH', 'MORN', 'MOS', 'MPC', 'MPLX', 'MPWR', 'MRK', 'MRNA', 'MRVL', 'MS', 'MSCI', 'MSFT', 'MSI', 'MSTR', 'MTB', 'MTZ', 'MU', 'NBIX', 'NDAQ', 'NDSN', 'NEE', 'NEM', 'NET', 'NFLX', 'NI', 'NKE', 'NLY', 'NOC', 'NOW', 'NRG', 'NSC', 'NTAP', 'NTNX', 'NTRA', 'NTRS', 'NUE', 'NVDA', 'NVR', 'NWS', 'NWSA', 'O', 'OC', 'ODFL', 'OHI', 'OKE', 'OKTA', 'OMC', 'ON', 'ORCL', 'ORLY', 'OTIS', 'OWL', 'OXY', 'PAA', 'PAG', 'PANW', 'PARAA', 'PAYC', 'PAYX', 'PCAR', 'PCG', 'PCOR', 'PCTY', 'PEG', 'PEN', 'PEP', 'PFE', 'PFG', 'PFGC', 'PG', 'PGR', 'PH', 'PHM', 'PINS', 'PKG', 'PLD', 'PLTR', 'PM', 'PNC', 'PNW', 'PODD', 'POOL', 'PPC', 'PPG', 'PPL', 'PR', 'PRMB', 'PRU', 'PSA', 'PSTG', 'PSX', 'PTC', 'PWR', 'PYPL', 'QCOM', 'RBC', 'RBLX', 'RBRK', 'RCL', 'RDDT', 'REG', 'REGN', 'RF', 'RGA', 'RGLD', 'RIVN', 'RJF', 'RKLB', 'RKT', 'RL', 'RMD', 'ROK', 'ROKU', 'ROL', 'ROP', 'ROST', 'RPM', 'RPRX', 'RS', 'RSG', 'RTO', 'RTX', 'RVTY', 'RYAN', 'SBAC', 'SBUX', 'SCCO', 'SCHW', 'SCI', 'SE', 'SEIC', 'SFM', 'SGI', 'SHW', 'SJM', 'SLMBP', 'SMCI', 'SN', 'SNA', 'SNAP', 'SNOW', 'SNPS', 'SNX', 'SO', 'SOFI', 'SOJC', 'SOJD ...

# %%
# !python ../../scripts/core/gen_senales_parallel.py
# Out:
# Simbolos a procesar: 673
# Iniciando procesamiento paralelo con debug...
# ABNB: ejecutando 15 estrategias...
# ABNB: breakout_volumen -> 89 senales
# ABNB: cruce_medias -> 38 senales
# ABNB: ema_9_21_cruce -> 52 senales
# ABNB: ema_pullback -> sin senales
# ABNB: gap_open_strategy -> 74 senales
# ABNB: inside_bar_breakout -> sin senales
# ABNB: ma_envelope_reversals -> 678 senales
# ABNB: macd_cruce -> 95 senales
# ABNB: macd_hist_reversal -> 614 senales
# ABNB: mov_avg -> 63 senales
# ABNB: rsi_divergencia -> 121 senales
# ABNB: rsi_reversion -> 250 senales
# ABNB: sma_10_50_cruce -> 30 senales
# ABNB: soporte_resistencia -> 189 senales
# ABNB: volatilidad_contraria -> sin senales
#
# ABBV: ejecutando 15 estrategias...
# ABBV: breakout_volumen -> 260 senales
# ABBV: cruce_medias -> 111 senales
# ABBV: ema_9_21_cruce -> 129 senales
# ABBV: ema_pullback -> sin senales
# ABBV: gap_open_strategy -> 48 senales
# ABBV: inside_bar_breakout -> sin senales
# ABBV: ma_envelope_reversals -> 1268 senales
# ABBV: macd_cruce -> 239 senales
# ABBV: macd_hist_reversal -> 1628 senales
# ABBV: mov_avg -> 185 senales
# ABBV: rsi_divergencia -> 407 senales
# ABBV: rsi_reversion -> 873 senales
# ABBV: sma_10_50_cruce -> 75 senales
# ABBV: soporte_resistencia -> 550 senales
# ABBV: volatilidad_contraria -> 25 senales
#
# ACI: ejecutando 15 estrategias...
# ACI: breakout_volumen -> 95 senales
# ACI: cruce_medias -> 49 senales
# ACI: ema_9_21_cruce -> 61 senales
# ACI: ema_pullback -> sin senales
# ACI: gap_open_strategy -> 21 senales
# ACI: inside_bar_breakout -> sin senales
# ACI: ma_envelope_reversals -> 480 senales
# ACI: macd_cruce -> 98 senales
# ACI: macd_hist_reversal -> 656 senales
# ACI: mov_avg -> 85 senales
# ACI: rsi_divergencia -> 145 senales
# ACI: rsi_reversion -> 301 senales
# ACI: sma_10_50_cruce -> 27 senales
# ACI: soporte_resistencia -> 215 senales
# ACI: volatilidad_contraria -> 12 senales
#
# A: ejecutando 15 estrategias...
# A: breakout_volumen -> 438 senales
# A: cruce_medias -> 166 senales
# A: ema_9_21_cruce -> 208 senales
# A: ema_pullback -> sin senales
# A: gap_open_strategy -> 104 senales
# A: inside_bar_breakout -> sin senales
# A: ma_envelope_reversals -> 2272 senales
# A: macd_cruce -> 396 senales
# A: macd_hist_reversal -> 2624 senales
# A: mov_avg -> 306 senales
# A: rsi_divergencia -> 645 senales
# A: rsi_reversion -> 1312 senales
# A: sma_10_50_cruce -> 128 senales
# A: soporte_resistencia -> 937 senales
# A: volatilidad_contraria -> 5 senales
#
# AAPL: ejecutando 15 estrategias...
# AAPL: breakout_volumen -> 524 senales
# AAPL: cruce_medias -> 162 senales
# AAPL: ema_9_21_cruce -> 190 senales
# AAPL: ema_pullback -> sin senales
# AAPL: gap_open_strategy -> 150 senales
# AAPL: inside_bar_breakout -> sin senales
# AAPL: ma_envelope_reversals -> 2616 senales
# AAPL: macd_cruce -> 368 senales
# AAPL: macd_hist_reversal -> 2660 senales
# AAPL: mov_avg -> 267 senales
# AAPL: rsi_divergencia -> 725 senales
# AAPL: rsi_reversion -> 1569 senales
# AAPL: sma_10_50_cruce -> 128 senales
# AAPL: soporte_resistencia -> 1084 senales
# AAPL: volatilidad_contraria -> 24 senales
#
# ABT: ejecutando 15 estrategias...
# ABT: breakout_volumen -> 433 senales
# ABT: cruce_medias -> 174 senales
# ABT: ema_9_21_cruce -> 236 senales
# ABT: ema_pullback -> sin senales
# ABT: gap_open_strategy -> 44 senales
# ABT: inside_bar_breakout -> sin senales
# ABT: ma_envelope_reversals -> 1452 senales
# ABT: macd_cruce -> 427 senales
# ABT: macd_hist_reversal -> 2702 senales
# ABT: mov_avg -> 332 senales
# ABT: rsi_divergencia -> 620 senales
# ABT: rsi_reversion -> 1251 senales
# ABT: sma_10_50_cruce -> 127 senales
# ABT: soporte_resistencia -> 866 senales
# ABT: volatilidad_contraria -> 22 senales
#
# ACM: ejecutando 15 estrategias...
# ACM: breakout_volumen -> 385 senales
# ACM: cruce_medias -> 163 senales
# ACM: ema_9_21_cruce -> 207 senales
# ACM: ema_pullback -> sin senales
# ACM: gap_open_strategy -> 105 senales
# ACM: inside_bar_breakout -> sin senales
# ACM: ma_envelope_reversals -> 2271 senales
# ACM: macd_cruce -> 363 senales
# ACM: macd_hist_reversal -> 2390 senales
# ACM: mov_avg -> 298 senales
# ACM: rsi_divergencia -> 618 senales
# ACM: rsi_reversion -> 1243 senales
# ACM: sma_10_50_cruce -> 114 senales
# ACM: soporte_resistencia -> 820 senales
# ACM: volatilidad_contraria -> 27 senales
#
# ADBE: ejecutando 15 estrategias...
# ADBE: breakout_volumen -> 457 senales
# ADBE: cruce_medias -> 171 senales
# ADBE: ema_9_21_cruce -> 209 senales
# ADBE: ema_pullback -> sin senales
# ADBE: gap_open_strategy -> 149 senales
# ADBE: inside_bar_breakout -> sin senales
# ADBE: ma_envelope_reversals -> 2447 senales
# ADBE: macd_cruce -> 393 senales
# ADBE: macd_hist_reversal -> 2629 senales
# ADBE: mov_avg -> 307 senales
# ADBE: rsi_divergencia -> 699 senales
# ADBE: rsi_reversion -> 1375 senales
# ADBE: sma_10_50_cruce -> 125 senales
# ADBE: soporte_resistencia -> 966 senales
# ADBE: volatilidad_contraria -> 8 senales
#
# ADI: ejecutando 15 estrategias...
# ADI: breakout_volumen -> 403 senales
# ADI: cruce_medias -> 214 senales
# ADI: ema_9_21_cruce -> 262 senales
# ADI: ema_pullback -> sin senales
# ADI: gap_open_strategy -> 111 senales
# ADI: inside_bar_breakout -> sin senales
# ADI: ma_envelope_reversals -> 2153 senales
# ADI: macd_cruce -> 417 senales
# ADI: macd_hist_reversal -> 2675 senales
# ADI: mov_avg -> 338 senales
# ADI: rsi_divergencia -> 555 senales
# ADI: rsi_reversion -> 1115 senales
# ADI: sma_10_50_cruce -> 163 senales
# ADI: soporte_resistencia -> 875 senales
# ADI: volatilidad_contraria -> 6 senales
#
# ADM: ejecutando 15 estrategias...
# ADM: breakout_volumen -> 436 senales
# ADM: cruce_medias -> 185 senales
# ADM: ema_9_21_cruce -> 253 senales
# ADM: ema_pullback -> sin senales
# ADM: gap_open_strategy -> 89 senales
# ADM: inside_bar_breakout -> sin senales
# ADM: ma_envelope_reversals -> 2099 senales
# ADM: macd_cruce -> 414 senales
# ADM: macd_hist_reversal -> 2683 senales
# ADM: mov_avg -> 315 senales
# ADM: rsi_divergencia -> 588 senales
# ADM: rsi_reversion -> 1221 senales
# ADM: sma_10_50_cruce -> 132 senales
# ADM: soporte_resistencia -> 924 senales
# ADM: volatilidad_contraria -> 5 senales
#
# ADP: ejecutando 15 estrategias...
# ADP: breakout_volumen -> 367 senales
# ADP: cruce_medias -> 194 senales
# ADP: ema_9_21_cruce -> 256 senales
# ADP: ema_pullback -> sin senales
# ADP: gap_open_strategy -> 58 senales
# ADP: inside_bar_breakout -> sin senales
# ADP: ma_envelope_reversals -> 1367 senales
# ADP: macd_cruce -> 420 senales
# ADP: macd_hist_reversal -> 2637 senales
# ADP: mov_avg -> 354 senales
# ADP: rsi_divergencia -> 552 senales
# ADP: rsi_reversion -> 1165 senales
# ADP: sma_10_50_cruce -> 143 senales
# ADP: soporte_resistencia -> 879 senales
# ADP: volatilidad_contraria -> 34 senales
#
# ADSK: ejecutando 15 estrategias...
# ADSK: breakout_volumen -> 455 senales
# ADSK: cruce_medias -> 170 senales
# ADSK: ema_9_21_cruce -> 226 senales
# ADSK: ema_pullback -> sin senales
# ADSK: gap_open_strategy -> 159 senales
# ADSK: inside_bar_breakout -> sin senales
# ADSK: ma_envelope_reversals -> 2861 senales
# ADSK: macd_cruce -> 388 senales
# ADSK: macd_hist_reversal -> 2617 senales
# ADSK: mov_avg -> 312 senales
# ADSK: rsi_divergencia -> 724 senales
# ADSK: rsi_reversion -> 1417 senales
# ADSK: sma_10_50_cruce -> 128 senales
# ADSK: soporte_resistencia -> 984 senales
# ADSK: volatilidad_contraria -> 8 senales
#
# AEE: ejecutando 15 estrategias...
# AEE: breakout_volumen -> 355 senales
# AEE: cruce_medias -> 198 senales
# AEE: ema_9_21_cruce -> 250 senales
# AEE: ema_pullback -> sin senales
# AEE: gap_open_strategy -> 21 senales
# AEE: inside_bar_breakout -> sin senales
# AEE: ma_envelope_reversals -> 1236 senales
# AEE: macd_cruce -> 406 senales
# AEE: macd_hist_reversal -> 2696 senales
# AEE: mov_avg -> 328 senales
# AEE: rsi_divergencia -> 461 senales
# AEE: rsi_reversion -> 1053 senales
# AEE: sma_10_50_cruce -> 147 senales
# AEE: soporte_resistencia -> 898 senales
# AEE: volatilidad_contraria -> 32 senales
#
# AEP: ejecutando 15 estrategias...
# AEP: breakout_volumen -> 393 senales
# AEP: cruce_medias -> 157 senales
# AEP: ema_9_21_cruce -> 203 senales
# AEP: ema_pullback -> sin senales
# AEP: gap_open_strategy -> 23 senales
# AEP: inside_bar_breakout -> sin senales
# AEP: ma_envelope_reversals -> 1267 senales
# AEP: macd_cruce -> 423 senales
# AEP: macd_hist_reversal -> 2674 senales
# AEP: mov_avg -> 304 senales
# AEP: rsi_divergencia -> 528 senales
# AEP: rsi_reversion -> 1118 senales
# AEP: sma_10_50_cruce -> 113 senales
# AEP: soporte_resistencia -> 897 senales
# AEP: volatilidad_contraria -> 38 senales
#
# AFG: ejecutando 15 estrategias...
# AFG: breakout_volumen -> 376 senales
# AFG: cruce_medias -> 203 senales
# AFG: ema_9_21_cruce -> 257 senales
# AFG: ema_pullback -> sin senales
# AFG: gap_open_strategy -> 98 senales
# AFG: inside_bar_breakout -> sin senales
# AFG: ma_envelope_reversals -> 1369 senales
# AFG: macd_cruce -> 449 senales
# AFG: macd_hist_reversal -> 2695 senales
# AFG: mov_avg -> 357 senales
# AFG: rsi_divergencia -> 418 senales
# AFG: rsi_reversion -> 978 senales
# AFG: sma_10_50_cruce -> 139 senales
# AFG: soporte_resistencia -> 955 senales
# AFG: volatilidad_contraria -> 41 senales
#
# AFRM: ejecutando 15 estrategias...
# AFRM: breakout_volumen -> 96 senales
# AFRM: cruce_medias -> 35 senales
# AFRM: ema_9_21_cruce -> 45 senales
# AFRM: ema_pullback -> sin senales
# AFRM: gap_open_strategy -> 208 senales
# AFRM: inside_bar_breakout -> sin senales
# AFRM: ma_envelope_reversals -> 930 senales
# AFRM: macd_cruce -> 78 senales
# AFRM: macd_hist_reversal -> 570 senales
# AFRM: mov_avg -> 57 senales
# AFRM: rsi_divergencia -> 138 senales
# AFRM: rsi_reversion -> 293 senales
# AFRM: sma_10_50_cruce -> 23 senales
# AFRM: soporte_resistencia -> 204 senales
# AFRM: volatilidad_contraria -> 4 senales
#
# AGNCL: ejecutando 15 estrategias...
# AGNCL: breakout_volumen -> 39 senales
# AGNCL: cruce_medias -> 22 senales
# AGNCL: ema_9_21_cruce -> 34 senales
# AGNCL: ema_pullback -> sin senales
# AGNCL: gap_open_strategy -> 2 senales
# AGNCL: inside_bar_breakout -> sin senales
# AGNCL: ma_envelope_reversals -> 79 senales
# AGNCL: macd_cruce -> 59 senales
# AGNCL: macd_hist_reversal -> 368 senales
# AGNCL: mov_avg -> 45 senales
# AGNCL: rsi_divergencia -> 68 senales
# AGNCL: rsi_reversion -> 159 senales
# AGNCL: sma_10_50_cruce -> 16 senales
# AGNCL: soporte_resistencia -> 99 senales
# AGNCL: volatilidad_contraria -> 10 senales
#
# AGNCM: ejecutando 15 estrategias...
# AGNCM: breakout_volumen -> 94 senales
# AGNCM: cruce_medias -> 51 senales
# AGNCM: ema_9_21_cruce -> 67 senales
# AGNCM: ema_pullback -> sin senales
# AGNCM: gap_open_strategy -> 8 senales
# AGNCM: inside_bar_breakout -> sin senales
# AGNCM: ma_envelope_reversals -> 217 senales
# AGNCM: macd_cruce -> 127 senales
# AGNCM: macd_hist_reversal -> 822 senales
# AGNCM: mov_avg -> 104 senales
# AGNCM: rsi_divergencia -> 150 senales
# AGNCM: rsi_reversion -> 340 senales
# AGNCM: sma_10_50_cruce -> 40 senales
# AGNCM: soporte_resistencia -> 234 senales
# AGNCM: volatilidad_contraria -> 31 senales
#
# AFL: ejecutando 15 estrategias...
# AFL: breakout_volumen -> 385 senales
# AFL: cruce_medias -> 171 senales
# AFL: ema_9_21_cruce -> 219 senales
# AFL: ema_pullback -> sin senales
# AFL: gap_open_strategy -> 131 senales
# AFL: inside_bar_breakout -> sin senales
# AFL: ma_envelope_reversals -> 1582 senales
# AFL: macd_cruce -> 431 senales
# AFL: macd_hist_reversal -> 2684 senales
# AFL: mov_avg -> 322 senales
# AFL: rsi_divergencia -> 529 senales
# AFL: rsi_reversion -> 1130 senales
# AFL: sma_10_50_cruce -> 125 senales
# AFL: soporte_resistencia -> 879 senales
# AFL: volatilidad_contraria -> 42 senales
#
# AGNCO: ejecutando 15 estrategias...
# AGNCO: breakout_volumen -> 103 senales
# AGNCO: cruce_medias -> 47 senales
# AGNCO: ema_9_21_cruce -> 51 senales
# AGNCO: ema_pullback -> sin senales
# AGNCO: gap_open_strategy -> 10 senales
# AGNCO: inside_bar_breakout -> sin senales
# AGNCO: ma_envelope_reversals -> 191 senales
# AGNCO: macd_cruce -> 99 senales
# AGNCO: macd_hist_reversal -> 748 senales
# AGNCO: mov_avg -> 83 senales
# AGNCO: rsi_divergencia -> 153 senales
# AGNCO: rsi_reversion -> 353 senales
# AGNCO: sma_10_50_cruce -> 36 senales
# AGNCO: soporte_resistencia -> 242 senales
# AGNCO: volatilidad_contraria -> 39 senales
#
# AGNCN: ejecutando 15 estrategias...
# AGNCN: breakout_volumen -> 102 senales
# AGNCN: cruce_medias -> 91 senales
# AGNCN: ema_9_21_cruce -> 113 senales
# AGNCN: ema_pullback -> sin senales
# AGNCN: gap_open_strategy -> 8 senales
# AGNCN: inside_bar_breakout -> sin senales
# AGNCN: ma_envelope_reversals -> 133 senales
# AGNCN: macd_cruce -> 166 senales
# AGNCN: macd_hist_reversal -> 1006 senales
# AGNCN: mov_avg -> 136 senales
# AGNCN: rsi_divergencia -> 187 senales
# AGNCN: rsi_reversion -> 407 senales
# AGNCN: sma_10_50_cruce -> 78 senales
# AGNCN: soporte_resistencia -> 278 senales
# AGNCN: volatilidad_contraria -> 41 senales
#
# AGNCP: ejecutando 15 estrategias...
# AGNCP: breakout_volumen -> 76 senales
# AGNCP: cruce_medias -> 49 senales
# AGNCP: ema_9_21_cruce -> 57 senales
# AGNCP: ema_pullback -> sin senales
# AGNCP: gap_open_strategy -> 11 senales
# AGNCP: inside_bar_breakout -> sin senales
# AGNCP: ma_envelope_reversals -> 197 senales
# AGNCP: macd_cruce -> 102 senales
# AGNCP: macd_hist_reversal -> 703 senales
# AGNCP: mov_avg -> 73 senales
# AGNCP: rsi_divergencia -> 169 senales
# AGNCP: rsi_reversion -> 382 senales
# AGNCP: sma_10_50_cruce -> 33 senales
# AGNCP: soporte_resistencia -> 230 senales
# AGNCP: volatilidad_contraria -> 23 senales
#
# ALAB: ejecutando 15 estrategias...
# ALAB: breakout_volumen -> 32 senales
# ALAB: cruce_medias -> 5 senales
# ALAB: ema_9_21_cruce -> 7 senales
# ALAB: ema_pullback -> sin senales
# ALAB: gap_open_strategy -> 63 senales
# ALAB: inside_bar_breakout -> sin senales
# ALAB: ma_envelope_reversals -> 244 senales
# ALAB: macd_cruce -> 25 senales
# ALAB: macd_hist_reversal -> 156 senales
# ALAB: mov_avg -> 10 senales
# ALAB: rsi_divergencia -> 43 senales
# ALAB: rsi_reversion -> 95 senales
# ALAB: sma_10_50_cruce -> 3 senales
# ALAB: soporte_resistencia -> 50 senales
# ALAB: volatilidad_contraria -> sin senales
#
# AIG: ejecutando 15 estrategias...
# AIG: breakout_volumen -> 442 senales
# AIG: cruce_medias -> 175 senales
# AIG: ema_9_21_cruce -> 227 senales
# AIG: ema_pullback -> sin senales
# AIG: gap_open_strategy -> 271 senales
# AIG: inside_bar_breakout -> sin senales
# AIG: ma_envelope_reversals -> 2143 senales
# AIG: macd_cruce -> 392 senales
# AIG: macd_hist_reversal -> 2685 senales
# AIG: mov_avg -> 314 senales
# AIG: rsi_divergencia -> 644 senales
# AIG: rsi_reversion -> 1318 senales
# AIG: sma_10_50_cruce -> 122 senales
# AIG: soporte_resistencia -> 923 senales
# AIG: volatilidad_contraria -> 33 senales
#
# AJG: ejecutando 15 estrategias...
# AJG: breakout_volumen -> 354 senales
# AJG: cruce_medias -> 174 senales
# AJG: ema_9_21_cruce -> 234 senales
# AJG: ema_pullback -> sin senales
# AJG: gap_open_strategy -> 52 senales
# AJG: inside_bar_breakout -> sin senales
# AJG: ma_envelope_reversals -> 1296 senales
# AJG: macd_cruce -> 404 senales
# AJG: macd_hist_reversal -> 2700 senales
# AJG: mov_avg -> 313 senales
# AJG: rsi_divergencia -> 554 senales
# AJG: rsi_reversion -> 1179 senales
# AJG: sma_10_50_cruce -> 134 senales
# AJG: soporte_resistencia -> 934 senales
# AJG: volatilidad_contraria -> 24 senales
#
# AKAM: ejecutando 15 estrategias...
# AKAM: breakout_volumen -> 447 senales
# AKAM: cruce_medias -> 158 senales
# AKAM: ema_9_21_cruce -> 214 senales
# AKAM: ema_pullback -> sin senales
# AKAM: gap_open_strategy -> 148 senales
# AKAM: inside_bar_breakout -> sin senales
# AKAM: ma_envelope_reversals -> 2609 senales
# AKAM: macd_cruce -> 376 senales
# AKAM: macd_hist_reversal -> 2569 senales
# AKAM: mov_avg -> 301 senales
# AKAM: rsi_divergencia -> 755 senales
# AKAM: rsi_reversion -> 1410 senales
# AKAM: sma_10_50_cruce -> 130 senales
# AKAM: soporte_resistencia -> 925 senales
# AKAM: volatilidad_contraria -> 19 senales
#
# ALLE: ejecutando 15 estrategias...
# ALLE: breakout_volumen -> 229 senales
# ALLE: cruce_medias -> 100 senales
# ALLE: ema_9_21_cruce -> 130 senales
# ALLE: ema_pullback -> sin senales
# ALLE: gap_open_strategy -> 48 senales
# ALLE: inside_bar_breakout -> sin senales
# ALLE: ma_envelope_reversals -> 1110 senales
# ALLE: macd_cruce -> 241 senales
# ALLE: macd_hist_reversal -> 1544 senales
# ALLE: mov_avg -> 195 senales
# ALLE: rsi_divergencia -> 375 senales
# ALLE: rsi_reversion -> 745 senales
# ALLE: sma_10_50_cruce -> 74 senales
# ALLE: soporte_resistencia -> 520 senales
# ALLE: volatilidad_contraria -> 2 senales
#
# ALGN: ejecutando 15 estrategias...
# ALGN: breakout_volumen -> 411 senales
# ALGN: cruce_medias -> 142 senales
# ALGN: ema_9_21_cruce -> 197 senales
# ALGN: ema_pullback -> sin senales
# ALGN: gap_open_strategy -> 172 senales
# ALGN: inside_bar_breakout -> sin senales
# ALGN: ma_envelope_reversals -> 2933 senales
# ALGN: macd_cruce -> 373 senales
# ALGN: macd_hist_reversal -> 2543 senales
# ALGN: mov_avg -> 318 senales
# ALGN: rsi_divergencia -> 750 senales
# ALGN: rsi_reversion -> 1437 senales
# ALGN: sma_10_50_cruce -> 104 senales
# ALGN: soporte_resistencia -> 852 senales
# ALGN: volatilidad_contraria -> 16 senales
#
# ALLY: ejecutando 15 estrategias...
# ALLY: breakout_volumen -> 226 senales
# ALLY: cruce_medias -> 104 senales
# ALLY: ema_9_21_cruce -> 132 senales
# ALLY: ema_pullback -> sin senales
# ALLY: gap_open_strategy -> 122 senales
# ALLY: inside_bar_breakout -> sin senales
# ALLY: ma_envelope_reversals -> 1385 senales
# ALLY: macd_cruce -> 261 senales
# ALLY: macd_hist_reversal -> 1493 senales
# ALLY: mov_avg -> 181 senales
# ALLY: rsi_divergencia -> 358 senales
# ALLY: rsi_reversion -> 735 senales
# ALLY: sma_10_50_cruce -> 74 senales
# ALLY: soporte_resistencia -> 495 senales
# ALLY: volatilidad_contraria -> 25 senales
#
# ALL: ejecutando 15 estrategias...
# ALL: breakout_volumen -> 387 senales
# ALL: cruce_medias -> 176 senales
# ALL: ema_9_21_cruce -> 228 senales
# ALL: ema_pullback -> sin senales
# ALL: gap_open_strategy -> 86 senales
# ALL: inside_bar_breakout -> sin senales
# ALL: ma_envelope_reversals -> 1654 senales
# ALL: macd_cruce -> 426 senales
# ALL: macd_hist_reversal -> 2629 senales
# ALL: mov_avg -> 299 senales
# ALL: rsi_divergencia -> 593 senales
# ALL: rsi_reversion -> 1250 senales
# ALL: sma_10_50_cruce -> 129 senales
# ALL: soporte_resistencia -> 901 senales
# ALL: volatilidad_contraria -> 34 senales
#
# ALNY: ejecutando 15 estrategias...
# ALNY: breakout_volumen -> 440 senales
# ALNY: cruce_medias -> 181 senales
# ALNY: ema_9_21_cruce -> 223 senales
# ALNY: ema_pullback -> sin senales
# ALNY: gap_open_strategy -> 163 senales
# ALNY: inside_bar_breakout -> sin senales
# ALNY: ma_envelope_reversals -> 3310 senales
# ALNY: macd_cruce -> 357 senales
# ALNY: macd_hist_reversal -> 2562 senales
# ALNY: mov_avg -> 320 senales
# ALNY: rsi_divergencia -> 672 senales
# ALNY: rsi_reversion -> 1319 senales
# ALNY: sma_10_50_cruce -> 154 senales
# ALNY: soporte_resistencia -> 891 senales
# ALNY: volatilidad_contraria -> 43 senales
#
# AMAT: ejecutando 15 estrategias...
# AMAT: breakout_volumen -> 461 senales
# AMAT: cruce_medias -> 177 senales
# AMAT: ema_9_21_cruce -> 207 senales
# AMAT: ema_pullback -> sin senales
# AMAT: gap_open_strategy -> 186 senales
# AMAT: inside_bar_breakout -> sin senales
# AMAT: ma_envelope_reversals -> 2752 senales
# AMAT: macd_cruce -> 390 senales
# AMAT: macd_hist_reversal -> 2627 senales
# AMAT: mov_avg -> 298 senales
# AMAT: rsi_divergencia -> 584 senales
# AMAT: rsi_reversion -> 1201 senales
# AMAT: sma_10_50_cruce -> 127 senales
# AMAT: soporte_resistencia -> 926 senales
# AMAT: volatilidad_contraria -> 5 senales
#
# AMH: ejecutando 15 estrategias...
# AMH: breakout_volumen -> 187 senales
# AMH: cruce_medias -> 131 senales
# AMH: ema_9_21_cruce -> 163 senales
# AMH: ema_pullback -> sin senales
# AMH: gap_open_strategy -> 24 senales
# AMH: inside_bar_breakout -> sin senales
# AMH: ma_envelope_reversals -> 815 senales
# AMH: macd_cruce -> 270 senales
# AMH: macd_hist_reversal -> 1600 senales
# AMH: mov_avg -> 197 senales
# AMH: rsi_divergencia -> 291 senales
# AMH: rsi_reversion -> 634 senales
# AMH: sma_10_50_cruce -> 95 senales
# AMH: soporte_resistencia -> 507 senales
# AMH: volatilidad_contraria -> 13 senales
#
# AME: ejecutando 15 estrategias...
# AME: breakout_volumen -> 402 senales
# AME: cruce_medias -> 180 senales
# AME: ema_9_21_cruce -> 228 senales
# AME: ema_pullback -> sin senales
# AME: gap_open_strategy -> 75 senales
# AME: inside_bar_breakout -> sin senales
# AME: ma_envelope_reversals -> 1833 senales
# AME: macd_cruce -> 406 senales
# AME: macd_hist_reversal -> 2643 senales
# AME: mov_avg -> 337 senales
# AME: rsi_divergencia -> 607 senales
# AME: rsi_reversion -> 1253 senales
# AME: sma_10_50_cruce -> 133 senales
# AME: soporte_resistencia -> 964 senales
# AME: volatilidad_contraria -> 17 senales
#
# AMD: ejecutando 15 estrategias...
# AMD: breakout_volumen -> 507 senales
# AMD: cruce_medias -> 164 senales
# AMD: ema_9_21_cruce -> 212 senales
# AMD: ema_pullback -> sin senales
# AMD: gap_open_strategy -> 393 senales
# AMD: inside_bar_breakout -> sin senales
# AMD: ma_envelope_reversals -> 3527 senales
# AMD: macd_cruce -> 392 senales
# AMD: macd_hist_reversal -> 2639 senales
# AMD: mov_avg -> 292 senales
# AMD: rsi_divergencia -> 705 senales
# AMD: rsi_reversion -> 1487 senales
# AMD: sma_10_50_cruce -> 134 senales
# AMD: soporte_resistencia -> 938 senales
# AMD: volatilidad_contraria -> 15 senales
#
# AMGN: ejecutando 15 estrategias...
# AMGN: breakout_volumen -> 424 senales
# AMGN: cruce_medias -> 185 senales
# AMGN: ema_9_21_cruce -> 243 senales
# AMGN: ema_pullback -> sin senales
# AMGN: gap_open_strategy -> 72 senales
# AMGN: inside_bar_breakout -> sin senales
# AMGN: ma_envelope_reversals -> 1989 senales
# AMGN: macd_cruce -> 370 senales
# AMGN: macd_hist_reversal -> 2609 senales
# AMGN: mov_avg -> 301 senales
# AMGN: rsi_divergencia -> 681 senales
# AMGN: rsi_reversion -> 1376 senales
# AMGN: sma_10_50_cruce -> 147 senales
# AMGN: soporte_resistencia -> 908 senales
# AMGN: volatilidad_contraria -> 12 senales
#
# AMP: ejecutando 15 estrategias...
# AMP: breakout_volumen -> 452 senales
# AMP: cruce_medias -> 160 senales
# AMP: ema_9_21_cruce -> 218 senales
# AMP: ema_pullback -> sin senales
# AMP: gap_open_strategy -> 166 senales
# AMP: inside_bar_breakout -> sin senales
# AMP: ma_envelope_reversals -> 2381 senales
# AMP: macd_cruce -> 412 senales
# AMP: macd_hist_reversal -> 2656 senales
# AMP: mov_avg -> 313 senales
# AMP: rsi_divergencia -> 607 senales
# AMP: rsi_reversion -> 1233 senales
# AMP: sma_10_50_cruce -> 106 senales
# AMP: soporte_resistencia -> 975 senales
# AMP: volatilidad_contraria -> 32 senales
#
# AMT: ejecutando 15 estrategias...
# AMT: breakout_volumen -> 407 senales
# AMT: cruce_medias -> 169 senales
# AMT: ema_9_21_cruce -> 227 senales
# AMT: ema_pullback -> sin senales
# AMT: gap_open_strategy -> 47 senales
# AMT: inside_bar_breakout -> sin senales
# AMT: ma_envelope_reversals -> 1841 senales
# AMT: macd_cruce -> 407 senales
# AMT: macd_hist_reversal -> 2688 senales
# AMT: mov_avg -> 331 senales
# AMT: rsi_divergencia -> 532 senales
# AMT: rsi_reversion -> 1130 senales
# AMT: sma_10_50_cruce -> 133 senales
# AMT: soporte_resistencia -> 898 senales
# AMT: volatilidad_contraria -> 19 senales
#
# ANET: ejecutando 15 estrategias...
# ANET: breakout_volumen -> 262 senales
# ANET: cruce_medias -> 95 senales
# ANET: ema_9_21_cruce -> 109 senales
# ANET: ema_pullback -> sin senales
# ANET: gap_open_strategy -> 139 senales
# ANET: inside_bar_breakout -> sin senales
# ANET: ma_envelope_reversals -> 1774 senales
# ANET: macd_cruce -> 224 senales
# ANET: macd_hist_reversal -> 1476 senales
# ANET: mov_avg -> 154 senales
# ANET: rsi_divergencia -> 400 senales
# ANET: rsi_reversion -> 813 senales
# ANET: sma_10_50_cruce -> 74 senales
# ANET: soporte_resistencia -> 552 senales
# ANET: volatilidad_contraria -> 6 senales
#
# AMZN: ejecutando 15 estrategias...
# AMZN: breakout_volumen -> 475 senales
# AMZN: cruce_medias -> 153 senales
# AMZN: ema_9_21_cruce -> 195 senales
# AMZN: ema_pullback -> sin senales
# AMZN: gap_open_strategy -> 165 senales
# AMZN: inside_bar_breakout -> sin senales
# AMZN: ma_envelope_reversals -> 2689 senales
# AMZN: macd_cruce -> 395 senales
# AMZN: macd_hist_reversal -> 2609 senales
# AMZN: mov_avg -> 286 senales
# AMZN: rsi_divergencia -> 696 senales
# AMZN: rsi_reversion -> 1336 senales
# AMZN: sma_10_50_cruce -> 116 senales
# AMZN: soporte_resistencia -> 938 senales
# AMZN: volatilidad_contraria -> 24 senales
#
# APG: ejecutando 15 estrategias...
# APG: breakout_volumen -> 91 senales
# APG: cruce_medias -> 50 senales
# APG: ema_9_21_cruce -> 60 senales
# APG: ema_pullback -> sin senales
# APG: gap_open_strategy -> 34 senales
# APG: inside_bar_breakout -> sin senales
# APG: ma_envelope_reversals -> 723 senales
# APG: macd_cruce -> 99 senales
# APG: macd_hist_reversal -> 705 senales
# APG: mov_avg -> 68 senales
# APG: rsi_divergencia -> 153 senales
# APG: rsi_reversion -> 341 senales
# APG: sma_10_50_cruce -> 30 senales
# APG: soporte_resistencia -> 223 senales
# APG: volatilidad_contraria -> sin senales
#
# ANSS: ejecutando 15 estrategias...
# ANSS: breakout_volumen -> 389 senales
# ANSS: cruce_medias -> 192 senales
# ANSS: ema_9_21_cruce -> 248 senales
# ANSS: ema_pullback -> sin senales
# ANSS: gap_open_strategy -> 107 senales
# ANSS: inside_bar_breakout -> sin senales
# ANSS: ma_envelope_reversals -> 2141 senales
# ANSS: macd_cruce -> 430 senales
# ANSS: macd_hist_reversal -> 2657 senales
# ANSS: mov_avg -> 328 senales
# ANSS: rsi_divergencia -> 589 senales
# ANSS: rsi_reversion -> 1195 senales
# ANSS: sma_10_50_cruce -> 154 senales
# ANSS: soporte_resistencia -> 909 senales
# ANSS: volatilidad_contraria -> 16 senales
#
# AON: ejecutando 15 estrategias...
# AON: breakout_volumen -> 383 senales
# AON: cruce_medias -> 174 senales
# AON: ema_9_21_cruce -> 246 senales
# AON: ema_pullback -> sin senales
# AON: gap_open_strategy -> 47 senales
# AON: inside_bar_breakout -> sin senales
# AON: ma_envelope_reversals -> 1526 senales
# AON: macd_cruce -> 409 senales
# AON: macd_hist_reversal -> 2667 senales
# AON: mov_avg -> 328 senales
# AON: rsi_divergencia -> 614 senales
# AON: rsi_reversion -> 1276 senales
# AON: sma_10_50_cruce -> 135 senales
# AON: soporte_resistencia -> 898 senales
# AON: volatilidad_contraria -> 18 senales
#
# APD: ejecutando 15 estrategias...
# APD: breakout_volumen -> 424 senales
# APD: cruce_medias -> 196 senales
# APD: ema_9_21_cruce -> 230 senales
# APD: ema_pullback -> sin senales
# APD: gap_open_strategy -> 65 senales
# APD: inside_bar_breakout -> sin senales
# APD: ma_envelope_reversals -> 1725 senales
# APD: macd_cruce -> 429 senales
# APD: macd_hist_reversal -> 2705 senales
# APD: mov_avg -> 326 senales
# APD: rsi_divergencia -> 591 senales
# APD: rsi_reversion -> 1221 senales
# APD: sma_10_50_cruce -> 144 senales
# APD: soporte_resistencia -> 929 senales
# APD: volatilidad_contraria -> 26 senales
#
# APOS: ejecutando 15 estrategias...
# APOS: breakout_volumen -> 14 senales
# APOS: cruce_medias -> 28 senales
# APOS: ema_9_21_cruce -> 28 senales
# APOS: ema_pullback -> sin senales
# APOS: gap_open_strategy -> sin senales
# APOS: inside_bar_breakout -> sin senales
# APOS: ma_envelope_reversals -> sin senales
# APOS: macd_cruce -> 42 senales
# APOS: macd_hist_reversal -> 232 senales
# APOS: mov_avg -> 35 senales
# APOS: rsi_divergencia -> 33 senales
# APOS: rsi_reversion -> 62 senales
# APOS: sma_10_50_cruce -> 14 senales
# APOS: soporte_resistencia -> 51 senales
# APOS: volatilidad_contraria -> sin senales
#
# APO: ejecutando 15 estrategias...
# APO: breakout_volumen -> 297 senales
# APO: cruce_medias -> 132 senales
# APO: ema_9_21_cruce -> 160 senales
# APO: ema_pullback -> sin senales
# APO: gap_open_strategy -> 112 senales
# APO: inside_bar_breakout -> sin senales
# APO: ma_envelope_reversals -> 1922 senales
# APO: macd_cruce -> 305 senales
# APO: macd_hist_reversal -> 1921 senales
# APO: mov_avg -> 203 senales
# APO: rsi_divergencia -> 450 senales
# APO: rsi_reversion -> 982 senales
# APO: sma_10_50_cruce -> 83 senales
# APO: soporte_resistencia -> 648 senales
# APO: volatilidad_contraria -> 20 senales
#
# APP: ejecutando 15 estrategias...
# APP: breakout_volumen -> 95 senales
# APP: cruce_medias -> 28 senales
# APP: ema_9_21_cruce -> 36 senales
# APP: ema_pullback -> sin senales
# APP: gap_open_strategy -> 129 senales
# APP: inside_bar_breakout -> sin senales
# APP: ma_envelope_reversals -> 814 senales
# APP: macd_cruce -> 78 senales
# APP: macd_hist_reversal -> 540 senales
# APP: mov_avg -> 55 senales
# APP: rsi_divergencia -> 172 senales
# APP: rsi_reversion -> 351 senales
# APP: sma_10_50_cruce -> 14 senales
# APP: soporte_resistencia -> 207 senales
# APP: volatilidad_contraria -> 12 senales
#
# APH: ejecutando 15 estrategias...
# APH: breakout_volumen -> 381 senales
# APH: cruce_medias -> 160 senales
# APH: ema_9_21_cruce -> 206 senales
# APH: ema_pullback -> sin senales
# APH: gap_open_strategy -> 106 senales
# APH: inside_bar_breakout -> sin senales
# APH: ma_envelope_reversals -> 2015 senales
# APH: macd_cruce -> 397 senales
# APH: macd_hist_reversal -> 2642 senales
# APH: mov_avg -> 307 senales
# APH: rsi_divergencia -> 620 senales
# APH: rsi_reversion -> 1274 senales
# APH: sma_10_50_cruce -> 125 senales
# APH: soporte_resistencia -> 965 senales
# APH: volatilidad_contraria -> 10 senales
#
# AQNB: ejecutando 15 estrategias...
# AQNB: breakout_volumen -> 54 senales
# AQNB: cruce_medias -> 94 senales
# AQNB: ema_9_21_cruce -> 92 senales
# AQNB: ema_pullback -> sin senales
# AQNB: gap_open_strategy -> 6 senales
# AQNB: inside_bar_breakout -> sin senales
# AQNB: ma_envelope_reversals -> 118 senales
# AQNB: macd_cruce -> 140 senales
# AQNB: macd_hist_reversal -> 787 senales
# AQNB: mov_avg -> 100 senales
# AQNB: rsi_divergencia -> 148 senales
# AQNB: rsi_reversion -> 297 senales
# AQNB: sma_10_50_cruce -> 54 senales
# AQNB: soporte_resistencia -> 211 senales
# AQNB: volatilidad_contraria -> 24 senales
#
# AR: ejecutando 15 estrategias...
# AR: breakout_volumen -> 257 senales
# AR: cruce_medias -> 115 senales
# AR: ema_9_21_cruce -> 139 senales
# AR: ema_pullback -> sin senales
# AR: gap_open_strategy -> 188 senales
# AR: inside_bar_breakout -> sin senales
# AR: ma_envelope_reversals -> 1927 senales
# AR: macd_cruce -> 243 senales
# AR: macd_hist_reversal -> 1576 senales
# AR: mov_avg -> 186 senales
# AR: rsi_divergencia -> 367 senales
# AR: rsi_reversion -> 773 senales
# AR: sma_10_50_cruce -> 84 senales
# AR: soporte_resistencia -> 525 senales
# AR: volatilidad_contraria -> 4 senales
#
# ARES: ejecutando 15 estrategias...
# ARES: breakout_volumen -> 208 senales
# ARES: cruce_medias -> 94 senales
# ARES: ema_9_21_cruce -> 116 senales
# ARES: ema_pullback -> sin senales
# ARES: gap_open_strategy -> 68 senales
# ARES: inside_bar_breakout -> sin senales
# ARES: ma_envelope_reversals -> 1413 senales
# ARES: macd_cruce -> 215 senales
# ARES: macd_hist_reversal -> 1469 senales
# ARES: mov_avg -> 182 senales
# ARES: rsi_divergencia -> 385 senales
# ARES: rsi_reversion -> 791 senales
# ARES: sma_10_50_cruce -> 70 senales
# ARES: soporte_resistencia -> 477 senales
# ARES: volatilidad_contraria -> 5 senales
#
# ARCC: ejecutando 15 estrategias...
# ARCC: breakout_volumen -> 373 senales
# ARCC: cruce_medias -> 182 senales
# ARCC: ema_9_21_cruce -> 242 senales
# ARCC: ema_pullback -> sin senales
# ARCC: gap_open_strategy -> 126 senales
# ARCC: inside_bar_breakout -> sin senales
# ARCC: ma_envelope_reversals -> 1344 senales
# ARCC: macd_cruce -> 428 senales
# ARCC: macd_hist_reversal -> 2674 senales
# ARCC: mov_avg -> 306 senales
# ARCC: rsi_divergencia -> 542 senales
# ARCC: rsi_reversion -> 1187 senales
# ARCC: sma_10_50_cruce -> 133 senales
# ARCC: soporte_resistencia -> 818 senales
# ARCC: volatilidad_contraria -> 53 senales
#
# ARMK: ejecutando 15 estrategias...
# ARMK: breakout_volumen -> 206 senales
# ARMK: cruce_medias -> 99 senales
# ARMK: ema_9_21_cruce -> 133 senales
# ARMK: ema_pullback -> sin senales
# ARMK: gap_open_strategy -> 80 senales
# ARMK: inside_bar_breakout -> sin senales
# ARMK: ma_envelope_reversals -> 1109 senales
# ARMK: macd_cruce -> 245 senales
# ARMK: macd_hist_reversal -> 1541 senales
# ARMK: mov_avg -> 195 senales
# ARMK: rsi_divergencia -> 320 senales
# ARMK: rsi_reversion -> 669 senales
# ARMK: sma_10_50_cruce -> 74 senales
# ARMK: soporte_resistencia -> 468 senales
# ARMK: volatilidad_contraria -> 24 senales
#
# ARE: ejecutando 15 estrategias...
# ARE: breakout_volumen -> 363 senales
# ARE: cruce_medias -> 193 senales
# ARE: ema_9_21_cruce -> 249 senales
# ARE: ema_pullback -> sin senales
# ARE: gap_open_strategy -> 68 senales
# ARE: inside_bar_breakout -> sin senales
# ARE: ma_envelope_reversals -> 1880 senales
# ARE: macd_cruce -> 404 senales
# ARE: macd_hist_reversal -> 2720 senales
# ARE: mov_avg -> 330 senales
# ARE: rsi_divergencia -> 583 senales
# ARE: rsi_reversion -> 1218 senales
# ARE: sma_10_50_cruce -> 145 senales
# ARE: soporte_resistencia -> 920 senales
# ARE: volatilidad_contraria -> 22 senales
#
# ATI: ejecutando 15 estrategias...
# ATI: breakout_volumen -> 452 senales
# ATI: cruce_medias -> 188 senales
# ATI: ema_9_21_cruce -> 228 senales
# ATI: ema_pullback -> sin senales
# ATI: gap_open_strategy -> 307 senales
# ATI: inside_bar_breakout -> sin senales
# ATI: ma_envelope_reversals -> 3310 senales
# ATI: macd_cruce -> 369 senales
# ATI: macd_hist_reversal -> 2647 senales
# ATI: mov_avg -> 322 senales
# ATI: rsi_divergencia -> 665 senales
# ATI: rsi_reversion -> 1328 senales
# ATI: sma_10_50_cruce -> 146 senales
# ATI: soporte_resistencia -> 930 senales
# ATI: volatilidad_contraria -> 4 senales
#
# ATO: ejecutando 15 estrategias...
# ATO: breakout_volumen -> 321 senales
# ATO: cruce_medias -> 214 senales
# ATO: ema_9_21_cruce -> 265 senales
# ATO: ema_pullback -> sin senales
# ATO: gap_open_strategy -> 27 senales
# ATO: inside_bar_breakout -> sin senales
# ATO: ma_envelope_reversals -> 1234 senales
# ATO: macd_cruce -> 415 senales
# ATO: macd_hist_reversal -> 2664 senales
# ATO: mov_avg -> 315 senales
# ATO: rsi_divergencia -> 548 senales
# ATO: rsi_reversion -> 1154 senales
# ATO: sma_10_50_cruce -> 150 senales
# ATO: soporte_resistencia -> 885 senales
# ATO: volatilidad_contraria -> 30 senales
#
# ATR: ejecutando 15 estrategias...
# ATR: breakout_volumen -> 313 senales
# ATR: cruce_medias -> 206 senales
# ATR: ema_9_21_cruce -> 262 senales
# ATR: ema_pullback -> sin senales
# ATR: gap_open_strategy -> 48 senales
# ATR: inside_bar_breakout -> sin senales
# ATR: ma_envelope_reversals -> 1420 senales
# ATR: macd_cruce -> 452 senales
# ATR: macd_hist_reversal -> 2702 senales
# ATR: mov_avg -> 351 senales
# ATR: rsi_divergencia -> 562 senales
# ATR: rsi_reversion -> 1118 senales
# ATR: sma_10_50_cruce -> 145 senales
# ATR: soporte_resistencia -> 796 senales
# ATR: volatilidad_contraria -> 10 senales
#
# AUR: ejecutando 15 estrategias...
# AUR: breakout_volumen -> 79 senales
# AUR: cruce_medias -> 43 senales
# AUR: ema_9_21_cruce -> 51 senales
# AUR: ema_pullback -> sin senales
# AUR: gap_open_strategy -> 131 senales
# AUR: inside_bar_breakout -> sin senales
# AUR: ma_envelope_reversals -> 744 senales
# AUR: macd_cruce -> 87 senales
# AUR: macd_hist_reversal -> 527 senales
# AUR: mov_avg -> 62 senales
# AUR: rsi_divergencia -> 107 senales
# AUR: rsi_reversion -> 262 senales
# AUR: sma_10_50_cruce -> 32 senales
# AUR: soporte_resistencia -> 173 senales
# AUR: volatilidad_contraria -> 28 senales
#
# AVGO: ejecutando 15 estrategias...
# AVGO: breakout_volumen -> 338 senales
# AVGO: cruce_medias -> 155 senales
# AVGO: ema_9_21_cruce -> 207 senales
# AVGO: ema_pullback -> sin senales
# AVGO: gap_open_strategy -> 143 senales
# AVGO: inside_bar_breakout -> sin senales
# AVGO: ma_envelope_reversals -> 2115 senales
# AVGO: macd_cruce -> 321 senales
# AVGO: macd_hist_reversal -> 2130 senales
# AVGO: mov_avg -> 238 senales
# AVGO: rsi_divergencia -> 447 senales
# AVGO: rsi_reversion -> 895 senales
# AVGO: sma_10_50_cruce -> 123 senales
# AVGO: soporte_resistencia -> 728 senales
# AVGO: volatilidad_contraria -> 20 senales
#
# AVB: ejecutando 15 estrategias...
# AVB: breakout_volumen -> 383 senales
# AVB: cruce_medias -> 201 senales
# AVB: ema_9_21_cruce -> 239 senales
# AVB: ema_pullback -> sin senales
# AVB: gap_open_strategy -> 80 senales
# AVB: inside_bar_breakout -> sin senales
# AVB: ma_envelope_reversals -> 1729 senales
# AVB: macd_cruce -> 423 senales
# AVB: macd_hist_reversal -> 2688 senales
# AVB: mov_avg -> 322 senales
# AVB: rsi_divergencia -> 482 senales
# AVB: rsi_reversion -> 1031 senales
# AVB: sma_10_50_cruce -> 137 senales
# AVB: soporte_resistencia -> 934 senales
# AVB: volatilidad_contraria -> 26 senales
#
# AVY: ejecutando 15 estrategias...
# AVY: breakout_volumen -> 396 senales
# AVY: cruce_medias -> 184 senales
# AVY: ema_9_21_cruce -> 240 senales
# AVY: ema_pullback -> sin senales
# AVY: gap_open_strategy -> 87 senales
# AVY: inside_bar_breakout -> sin senales
# AVY: ma_envelope_reversals -> 1928 senales
# AVY: macd_cruce -> 384 senales
# AVY: macd_hist_reversal -> 2609 senales
# AVY: mov_avg -> 334 senales
# AVY: rsi_divergencia -> 620 senales
# AVY: rsi_reversion -> 1300 senales
# AVY: sma_10_50_cruce -> 147 senales
# AVY: soporte_resistencia -> 894 senales
# AVY: volatilidad_contraria -> 8 senales
#
# AWK: ejecutando 15 estrategias...
# AWK: breakout_volumen -> 315 senales
# AWK: cruce_medias -> 158 senales
# AWK: ema_9_21_cruce -> 196 senales
# AWK: ema_pullback -> sin senales
# AWK: gap_open_strategy -> 25 senales
# AWK: inside_bar_breakout -> sin senales
# AWK: ma_envelope_reversals -> 1236 senales
# AWK: macd_cruce -> 375 senales
# AWK: macd_hist_reversal -> 2357 senales
# AWK: mov_avg -> 273 senales
# AWK: rsi_divergencia -> 497 senales
# AWK: rsi_reversion -> 1022 senales
# AWK: sma_10_50_cruce -> 113 senales
# AWK: soporte_resistencia -> 753 senales
# AWK: volatilidad_contraria -> 21 senales
#
# AXP: ejecutando 15 estrategias...
# AXP: breakout_volumen -> 462 senales
# AXP: cruce_medias -> 179 senales
# AXP: ema_9_21_cruce -> 215 senales
# AXP: ema_pullback -> sin senales
# AXP: gap_open_strategy -> 150 senales
# AXP: inside_bar_breakout -> sin senales
# AXP: ma_envelope_reversals -> 1968 senales
# AXP: macd_cruce -> 426 senales
# AXP: macd_hist_reversal -> 2674 senales
# AXP: mov_avg -> 336 senales
# AXP: rsi_divergencia -> 613 senales
# AXP: rsi_reversion -> 1237 senales
# AXP: sma_10_50_cruce -> 132 senales
# AXP: soporte_resistencia -> 935 senales
# AXP: volatilidad_contraria -> 21 senales
#
# AXON: ejecutando 15 estrategias...
# AXON: breakout_volumen -> 435 senales
# AXON: cruce_medias -> 161 senales
# AXON: ema_9_21_cruce -> 209 senales
# AXON: ema_pullback -> sin senales
# AXON: gap_open_strategy -> 307 senales
# AXON: inside_bar_breakout -> sin senales
# AXON: ma_envelope_reversals -> 3255 senales
# AXON: macd_cruce -> 337 senales
# AXON: macd_hist_reversal -> 2570 senales
# AXON: mov_avg -> 305 senales
# AXON: rsi_divergencia -> 749 senales
# AXON: rsi_reversion -> 1513 senales
# AXON: sma_10_50_cruce -> 129 senales
# AXON: soporte_resistencia -> 902 senales
# AXON: volatilidad_contraria -> 44 senales
#
# AZO: ejecutando 15 estrategias...
# AZO: breakout_volumen -> 394 senales
# AZO: cruce_medias -> 177 senales
# AZO: ema_9_21_cruce -> 223 senales
# AZO: ema_pullback -> sin senales
# AZO: gap_open_strategy -> 62 senales
# AZO: inside_bar_breakout -> sin senales
# AZO: ma_envelope_reversals -> 1794 senales
# AZO: macd_cruce -> 441 senales
# AZO: macd_hist_reversal -> 2691 senales
# AZO: mov_avg -> 302 senales
# AZO: rsi_divergencia -> 670 senales
# AZO: rsi_reversion -> 1357 senales
# AZO: sma_10_50_cruce -> 127 senales
# AZO: soporte_resistencia -> 887 senales
# AZO: volatilidad_contraria -> 13 senales
#
# BA: ejecutando 15 estrategias...
# BA: breakout_volumen -> 470 senales
# BA: cruce_medias -> 183 senales
# BA: ema_9_21_cruce -> 221 senales
# BA: ema_pullback -> sin senales
# BA: gap_open_strategy -> 153 senales
# BA: inside_bar_breakout -> sin senales
# BA: ma_envelope_reversals -> 2296 senales
# BA: macd_cruce -> 394 senales
# BA: macd_hist_reversal -> 2626 senales
# BA: mov_avg -> 312 senales
# BA: rsi_divergencia -> 674 senales
# BA: rsi_reversion -> 1332 senales
# BA: sma_10_50_cruce -> 133 senales
# BA: soporte_resistencia -> 930 senales
# BA: volatilidad_contraria -> 23 senales
#
# BAH: ejecutando 15 estrategias...
# BAH: breakout_volumen -> 279 senales
# BAH: cruce_medias -> 132 senales
# BAH: ema_9_21_cruce -> 164 senales
# BAH: ema_pullback -> sin senales
# BAH: gap_open_strategy -> 65 senales
# BAH: inside_bar_breakout -> sin senales
# BAH: ma_envelope_reversals -> 1523 senales
# BAH: macd_cruce -> 255 senales
# BAH: macd_hist_reversal -> 1916 senales
# BAH: mov_avg -> 205 senales
# BAH: rsi_divergencia -> 547 senales
# BAH: rsi_reversion -> 1067 senales
# BAH: sma_10_50_cruce -> 95 senales
# BAH: soporte_resistencia -> 644 senales
# BAH: volatilidad_contraria -> 7 senales
#
# BAC: ejecutando 15 estrategias...
# BAC: breakout_volumen -> 524 senales
# BAC: cruce_medias -> 165 senales
# BAC: ema_9_21_cruce -> 225 senales
# BAC: ema_pullback -> sin senales
# BAC: gap_open_strategy -> 244 senales
# BAC: inside_bar_breakout -> sin senales
# BAC: ma_envelope_reversals -> 2468 senales
# BAC: macd_cruce -> 361 senales
# BAC: macd_hist_reversal -> 2587 senales
# BAC: mov_avg -> 305 senales
# BAC: rsi_divergencia -> 703 senales
# BAC: rsi_reversion -> 1411 senales
# BAC: sma_10_50_cruce -> 115 senales
# BAC: soporte_resistencia -> 926 senales
# BAC: volatilidad_contraria -> 33 senales
#
# BALL: ejecutando 15 estrategias...
# BALL: breakout_volumen -> 394 senales
# BALL: cruce_medias -> 180 senales
# BALL: ema_9_21_cruce -> 230 senales
# BALL: ema_pullback -> sin senales
# BALL: gap_open_strategy -> 63 senales
# BALL: inside_bar_breakout -> sin senales
# BALL: ma_envelope_reversals -> 1771 senales
# BALL: macd_cruce -> 413 senales
# BALL: macd_hist_reversal -> 2672 senales
# BALL: mov_avg -> 321 senales
# BALL: rsi_divergencia -> 558 senales
# BALL: rsi_reversion -> 1132 senales
# BALL: sma_10_50_cruce -> 119 senales
# BALL: soporte_resistencia -> 887 senales
# BALL: volatilidad_contraria -> 12 senales
#
# BAX: ejecutando 15 estrategias...
# BAX: breakout_volumen -> 430 senales
# BAX: cruce_medias -> 187 senales
# BAX: ema_9_21_cruce -> 215 senales
# BAX: ema_pullback -> sin senales
# BAX: gap_open_strategy -> 56 senales
# BAX: inside_bar_breakout -> sin senales
# BAX: ma_envelope_reversals -> 1645 senales
# BAX: macd_cruce -> 403 senales
# BAX: macd_hist_reversal -> 2624 senales
# BAX: mov_avg -> 289 senales
# BAX: rsi_divergencia -> 637 senales
# BAX: rsi_reversion -> 1284 senales
# BAX: sma_10_50_cruce -> 125 senales
# BAX: soporte_resistencia -> 888 senales
# BAX: volatilidad_contraria -> 21 senales
#
# BEPC: ejecutando 15 estrategias...
# BEPC: breakout_volumen -> 115 senales
# BEPC: cruce_medias -> 48 senales
# BEPC: ema_9_21_cruce -> 66 senales
# BEPC: ema_pullback -> sin senales
# BEPC: gap_open_strategy -> 13 senales
# BEPC: inside_bar_breakout -> sin senales
# BEPC: ma_envelope_reversals -> 713 senales
# BEPC: macd_cruce -> 83 senales
# BEPC: macd_hist_reversal -> 652 senales
# BEPC: mov_avg -> 78 senales
# BEPC: rsi_divergencia -> 163 senales
# BEPC: rsi_reversion -> 352 senales
# BEPC: sma_10_50_cruce -> 32 senales
# BEPC: soporte_resistencia -> 249 senales
# BEPC: volatilidad_contraria -> sin senales
#
# BBY: ejecutando 15 estrategias...
# BBY: breakout_volumen -> 406 senales
# BBY: cruce_medias -> 166 senales
# BBY: ema_9_21_cruce -> 232 senales
# BBY: ema_pullback -> sin senales
# BBY: gap_open_strategy -> 190 senales
# BBY: inside_bar_breakout -> sin senales
# BBY: ma_envelope_reversals -> 2718 senales
# BBY: macd_cruce -> 428 senales
# BBY: macd_hist_reversal -> 2646 senales
# BBY: mov_avg -> 320 senales
# BBY: rsi_divergencia -> 673 senales
# BBY: rsi_reversion -> 1338 senales
# BBY: sma_10_50_cruce -> 133 senales
# BBY: soporte_resistencia -> 904 senales
# BBY: volatilidad_contraria -> 11 senales
#
# BDX: ejecutando 15 estrategias...
# BDX: breakout_volumen -> 377 senales
# BDX: cruce_medias -> 193 senales
# BDX: ema_9_21_cruce -> 239 senales
# BDX: ema_pullback -> sin senales
# BDX: gap_open_strategy -> 50 senales
# BDX: inside_bar_breakout -> sin senales
# BDX: ma_envelope_reversals -> 1303 senales
# BDX: macd_cruce -> 412 senales
# BDX: macd_hist_reversal -> 2662 senales
# BDX: mov_avg -> 321 senales
# BDX: rsi_divergencia -> 554 senales
# BDX: rsi_reversion -> 1134 senales
# BDX: sma_10_50_cruce -> 145 senales
# BDX: soporte_resistencia -> 886 senales
# BDX: volatilidad_contraria -> 16 senales
#
# BEN: ejecutando 15 estrategias...
# BEN: breakout_volumen -> 451 senales
# BEN: cruce_medias -> 186 senales
# BEN: ema_9_21_cruce -> 222 senales
# BEN: ema_pullback -> sin senales
# BEN: gap_open_strategy -> 106 senales
# BEN: inside_bar_breakout -> sin senales
# BEN: ma_envelope_reversals -> 2309 senales
# BEN: macd_cruce -> 398 senales
# BEN: macd_hist_reversal -> 2694 senales
# BEN: mov_avg -> 333 senales
# BEN: rsi_divergencia -> 578 senales
# BEN: rsi_reversion -> 1154 senales
# BEN: sma_10_50_cruce -> 138 senales
# BEN: soporte_resistencia -> 956 senales
# BEN: volatilidad_contraria -> 12 senales
#
# BJ: ejecutando 15 estrategias...
# BJ: breakout_volumen -> 130 senales
# BJ: cruce_medias -> 57 senales
# BJ: ema_9_21_cruce -> 83 senales
# BJ: ema_pullback -> sin senales
# BJ: gap_open_strategy -> 36 senales
# BJ: inside_bar_breakout -> sin senales
# BJ: ma_envelope_reversals -> 876 senales
# BJ: macd_cruce -> 141 senales
# BJ: macd_hist_reversal -> 918 senales
# BJ: mov_avg -> 112 senales
# BJ: rsi_divergencia -> 195 senales
# BJ: rsi_reversion -> 399 senales
# BJ: sma_10_50_cruce -> 39 senales
# BJ: soporte_resistencia -> 267 senales
# BJ: volatilidad_contraria -> 21 senales
#
# BG: ejecutando 15 estrategias...
# BG: breakout_volumen -> 421 senales
# BG: cruce_medias -> 198 senales
# BG: ema_9_21_cruce -> 214 senales
# BG: ema_pullback -> sin senales
# BG: gap_open_strategy -> 116 senales
# BG: inside_bar_breakout -> sin senales
# BG: ma_envelope_reversals -> 2283 senales
# BG: macd_cruce -> 403 senales
# BG: macd_hist_reversal -> 2642 senales
# BG: mov_avg -> 314 senales
# BG: rsi_divergencia -> 676 senales
# BG: rsi_reversion -> 1323 senales
# BG: sma_10_50_cruce -> 133 senales
# BG: soporte_resistencia -> 872 senales
# BG: volatilidad_contraria -> 2 senales
#
# BIIB: ejecutando 15 estrategias...
# BIIB: breakout_volumen -> 433 senales
# BIIB: cruce_medias -> 183 senales
# BIIB: ema_9_21_cruce -> 221 senales
# BIIB: ema_pullback -> sin senales
# BIIB: gap_open_strategy -> 108 senales
# BIIB: inside_bar_breakout -> sin senales
# BIIB: ma_envelope_reversals -> 2385 senales
# BIIB: macd_cruce -> 401 senales
# BIIB: macd_hist_reversal -> 2651 senales
# BIIB: mov_avg -> 308 senales
# BIIB: rsi_divergencia -> 687 senales
# BIIB: rsi_reversion -> 1286 senales
# BIIB: sma_10_50_cruce -> 133 senales
# BIIB: soporte_resistencia -> 857 senales
# BIIB: volatilidad_contraria -> 31 senales
#
# BK: ejecutando 15 estrategias...
# BK: breakout_volumen -> 395 senales
# BK: cruce_medias -> 175 senales
# BK: ema_9_21_cruce -> 215 senales
# BK: ema_pullback -> sin senales
# BK: gap_open_strategy -> 153 senales
# BK: inside_bar_breakout -> sin senales
# BK: ma_envelope_reversals -> 2001 senales
# BK: macd_cruce -> 397 senales
# BK: macd_hist_reversal -> 2678 senales
# BK: mov_avg -> 314 senales
# BK: rsi_divergencia -> 624 senales
# BK: rsi_reversion -> 1239 senales
# BK: sma_10_50_cruce -> 137 senales
# BK: soporte_resistencia -> 876 senales
# BK: volatilidad_contraria -> 32 senales
#
# BKNG: ejecutando 15 estrategias...
# BKNG: breakout_volumen -> 454 senales
# BKNG: cruce_medias -> 173 senales
# BKNG: ema_9_21_cruce -> 221 senales
# BKNG: ema_pullback -> sin senales
# BKNG: gap_open_strategy -> 172 senales
# BKNG: inside_bar_breakout -> sin senales
# BKNG: ma_envelope_reversals -> 2588 senales
# BKNG: macd_cruce -> 408 senales
# BKNG: macd_hist_reversal -> 2629 senales
# BKNG: mov_avg -> 304 senales
# BKNG: rsi_divergencia -> 711 senales
# BKNG: rsi_reversion -> 1388 senales
# BKNG: sma_10_50_cruce -> 129 senales
# BKNG: soporte_resistencia -> 939 senales
# BKNG: volatilidad_contraria -> 5 senales
#
# BKR: ejecutando 15 estrategias...
# BKR: breakout_volumen -> 418 senales
# BKR: cruce_medias -> 179 senales
# BKR: ema_9_21_cruce -> 227 senales
# BKR: ema_pullback -> sin senales
# BKR: gap_open_strategy -> 187 senales
# BKR: inside_bar_breakout -> sin senales
# BKR: ma_envelope_reversals -> 2800 senales
# BKR: macd_cruce -> 386 senales
# BKR: macd_hist_reversal -> 2616 senales
# BKR: mov_avg -> 306 senales
# BKR: rsi_divergencia -> 617 senales
# BKR: rsi_reversion -> 1266 senales
# BKR: sma_10_50_cruce -> 133 senales
# BKR: soporte_resistencia -> 893 senales
# BKR: volatilidad_contraria -> 4 senales
#
# BLDR: ejecutando 15 estrategias...
# BLDR: breakout_volumen -> 424 senales
# BLDR: cruce_medias -> 169 senales
# BLDR: ema_9_21_cruce -> 203 senales
# BLDR: ema_pullback -> sin senales
# BLDR: gap_open_strategy -> 282 senales
# BLDR: inside_bar_breakout -> sin senales
# BLDR: ma_envelope_reversals -> 3373 senales
# BLDR: macd_cruce -> 403 senales
# BLDR: macd_hist_reversal -> 2670 senales
# BLDR: mov_avg -> 311 senales
# BLDR: rsi_divergencia -> 662 senales
# BLDR: rsi_reversion -> 1320 senales
# BLDR: sma_10_50_cruce -> 119 senales
# BLDR: soporte_resistencia -> 871 senales
# BLDR: volatilidad_contraria -> 15 senales
#
# BLK: ejecutando 15 estrategias...
# BLK: breakout_volumen -> 464 senales
# BLK: cruce_medias -> 178 senales
# BLK: ema_9_21_cruce -> 228 senales
# BLK: ema_pullback -> sin senales
# BLK: gap_open_strategy -> 135 senales
# BLK: inside_bar_breakout -> sin senales
# BLK: ma_envelope_reversals -> 2231 senales
# BLK: macd_cruce -> 404 senales
# BLK: macd_hist_reversal -> 2663 senales
# BLK: mov_avg -> 293 senales
# BLK: rsi_divergencia -> 619 senales
# BLK: rsi_reversion -> 1315 senales
# BLK: sma_10_50_cruce -> 128 senales
# BLK: soporte_resistencia -> 953 senales
# ...
# WELL: volatilidad_contraria -> 20 senales
#
# WMG: ejecutando 15 estrategias...
# WMG: breakout_volumen -> 87 senales
# WMG: cruce_medias -> 45 senales
# WMG: ema_9_21_cruce -> 53 senales
# WMG: ema_pullback -> sin senales
# WMG: gap_open_strategy -> 33 senales
# WMG: inside_bar_breakout -> sin senales
# WMG: ma_envelope_reversals -> 712 senales
# WMG: macd_cruce -> 95 senales
# WMG: macd_hist_reversal -> 664 senales
# WMG: mov_avg -> 78 senales
# WMG: rsi_divergencia -> 172 senales
# WMG: rsi_reversion -> 338 senales
# WMG: sma_10_50_cruce -> 34 senales
# WMG: soporte_resistencia -> 204 senales
# WMG: volatilidad_contraria -> sin senales
#
# WFC: ejecutando 15 estrategias...
# WFC: breakout_volumen -> 470 senales
# WFC: cruce_medias -> 177 senales
# WFC: ema_9_21_cruce -> 217 senales
# WFC: ema_pullback -> sin senales
# WFC: gap_open_strategy -> 184 senales
# WFC: inside_bar_breakout -> sin senales
# WFC: ma_envelope_reversals -> 1955 senales
# WFC: macd_cruce -> 412 senales
# WFC: macd_hist_reversal -> 2667 senales
# WFC: mov_avg -> 353 senales
# WFC: rsi_divergencia -> 531 senales
# WFC: rsi_reversion -> 1115 senales
# WFC: sma_10_50_cruce -> 129 senales
# WFC: soporte_resistencia -> 884 senales
# WFC: volatilidad_contraria -> 30 senales
#
# WM: ejecutando 15 estrategias...
# WM: breakout_volumen -> 399 senales
# WM: cruce_medias -> 160 senales
# WM: ema_9_21_cruce -> 220 senales
# WM: ema_pullback -> sin senales
# WM: gap_open_strategy -> 35 senales
# WM: inside_bar_breakout -> sin senales
# WM: ma_envelope_reversals -> 1223 senales
# WM: macd_cruce -> 408 senales
# WM: macd_hist_reversal -> 2652 senales
# WM: mov_avg -> 321 senales
# WM: rsi_divergencia -> 615 senales
# WM: rsi_reversion -> 1305 senales
# WM: sma_10_50_cruce -> 126 senales
# WM: soporte_resistencia -> 901 senales
# WM: volatilidad_contraria -> 37 senales
#
# WMB: ejecutando 15 estrategias...
# WMB: breakout_volumen -> 417 senales
# WMB: cruce_medias -> 166 senales
# WMB: ema_9_21_cruce -> 196 senales
# WMB: ema_pullback -> sin senales
# WMB: gap_open_strategy -> 137 senales
# WMB: inside_bar_breakout -> sin senales
# WMB: ma_envelope_reversals -> 2434 senales
# WMB: macd_cruce -> 419 senales
# WMB: macd_hist_reversal -> 2704 senales
# WMB: mov_avg -> 291 senales
# WMB: rsi_divergencia -> 585 senales
# WMB: rsi_reversion -> 1228 senales
# WMB: sma_10_50_cruce -> 135 senales
# WMB: soporte_resistencia -> 894 senales
# WMB: volatilidad_contraria -> 31 senales
#
# Simbolos a procesar: 673
# Simbolos a procesar: 673
# Simbolos a procesar: 673
# Simbolos a procesar: 673
# Simbolos a procesar: 673
# Simbolos a procesar: 673
# Simbolos a procesar: 673
# Simbolos a procesar: 673
# WMT: ejecutando 15 estrategias...
# WMT: breakout_volumen -> 404 senales
# WMT: cruce_medias -> 177 senales
# WMT: ema_9_21_cruce -> 229 senales
# WMT: ema_pullback -> sin senales
# WMT: gap_open_strategy -> 46 senales
# WMT: inside_bar_breakout -> sin senales
# WMT: ma_envelope_reversals -> 1259 senales
# WMT: macd_cruce -> 394 senales
# WMT: macd_hist_reversal -> 2673 senales
# WMT: mov_avg -> 310 senales
# WMT: rsi_divergencia -> 620 senales
# WMT: rsi_reversion -> 1321 senales
# WMT: sma_10_50_cruce -> 125 senales
# WMT: soporte_resistencia -> 879 senales
# WMT: volatilidad_contraria -> 26 senales
#
# WRB: ejecutando 15 estrategias...
# WRB: breakout_volumen -> 374 senales
# WRB: cruce_medias -> 188 senales
# WRB: ema_9_21_cruce -> 248 senales
# WRB: ema_pullback -> sin senales
# WRB: gap_open_strategy -> 72 senales
# WRB: inside_bar_breakout -> sin senales
# WRB: ma_envelope_reversals -> 1392 senales
# WRB: macd_cruce -> 409 senales
# WRB: macd_hist_reversal -> 2692 senales
# WRB: mov_avg -> 336 senales
# WRB: rsi_divergencia -> 489 senales
# WRB: rsi_reversion -> 1078 senales
# WRB: sma_10_50_cruce -> 124 senales
# WRB: soporte_resistencia -> 906 senales
# WRB: volatilidad_contraria -> 20 senales
#
# WPC: ejecutando 15 estrategias...
# WPC: breakout_volumen -> 404 senales
# WPC: cruce_medias -> 170 senales
# WPC: ema_9_21_cruce -> 210 senales
# WPC: ema_pullback -> sin senales
# WPC: gap_open_strategy -> 66 senales
# WPC: inside_bar_breakout -> sin senales
# WPC: ma_envelope_reversals -> 1588 senales
# WPC: macd_cruce -> 372 senales
# WPC: macd_hist_reversal -> 2649 senales
# WPC: mov_avg -> 316 senales
# WPC: rsi_divergencia -> 633 senales
# WPC: rsi_reversion -> 1276 senales
# WPC: sma_10_50_cruce -> 124 senales
# WPC: soporte_resistencia -> 862 senales
# WPC: volatilidad_contraria -> 45 senales
#
# WSM: ejecutando 15 estrategias...
# WSM: breakout_volumen -> 422 senales
# WSM: cruce_medias -> 192 senales
# WSM: ema_9_21_cruce -> 244 senales
# WSM: ema_pullback -> sin senales
# WSM: gap_open_strategy -> 183 senales
# WSM: inside_bar_breakout -> sin senales
# WSM: ma_envelope_reversals -> 2751 senales
# WSM: macd_cruce -> 431 senales
# WSM: macd_hist_reversal -> 2649 senales
# WSM: mov_avg -> 328 senales
# WSM: rsi_divergencia -> 594 senales
# WSM: rsi_reversion -> 1181 senales
# WSM: sma_10_50_cruce -> 144 senales
# WSM: soporte_resistencia -> 888 senales
# WSM: volatilidad_contraria -> 9 senales
#
# WSO: ejecutando 15 estrategias...
# WSO: breakout_volumen -> 333 senales
# WSO: cruce_medias -> 167 senales
# WSO: ema_9_21_cruce -> 231 senales
# WSO: ema_pullback -> sin senales
# WSO: gap_open_strategy -> 79 senales
# WSO: inside_bar_breakout -> sin senales
# WSO: ma_envelope_reversals -> 2445 senales
# WSO: macd_cruce -> 391 senales
# WSO: macd_hist_reversal -> 2636 senales
# WSO: mov_avg -> 330 senales
# WSO: rsi_divergencia -> 575 senales
# WSO: rsi_reversion -> 1192 senales
# WSO: sma_10_50_cruce -> 120 senales
# WSO: soporte_resistencia -> 892 senales
# WSO: volatilidad_contraria -> 26 senales
#
# WST: ejecutando 15 estrategias...
# WST: breakout_volumen -> 365 senales
# WST: cruce_medias -> 145 senales
# WST: ema_9_21_cruce -> 195 senales
# WST: ema_pullback -> sin senales
# WST: gap_open_strategy -> 63 senales
# WST: inside_bar_breakout -> sin senales
# WST: ma_envelope_reversals -> 2132 senales
# WST: macd_cruce -> 407 senales
# WST: macd_hist_reversal -> 2662 senales
# WST: mov_avg -> 310 senales
# WST: rsi_divergencia -> 652 senales
# WST: rsi_reversion -> 1338 senales
# WST: sma_10_50_cruce -> 115 senales
# WST: soporte_resistencia -> 861 senales
# WST: volatilidad_contraria -> 15 senales
#
# WTRG: ejecutando 15 estrategias...
# WTRG: breakout_volumen -> 374 senales
# WTRG: cruce_medias -> 211 senales
# WTRG: ema_9_21_cruce -> 233 senales
# WTRG: ema_pullback -> sin senales
# WTRG: gap_open_strategy -> 31 senales
# WTRG: inside_bar_breakout -> sin senales
# WTRG: ma_envelope_reversals -> 1560 senales
# WTRG: macd_cruce -> 419 senales
# WTRG: macd_hist_reversal -> 2706 senales
# WTRG: mov_avg -> 327 senales
# WTRG: rsi_divergencia -> 555 senales
# WTRG: rsi_reversion -> 1196 senales
# WTRG: sma_10_50_cruce -> 163 senales
# WTRG: soporte_resistencia -> 903 senales
# WTRG: volatilidad_contraria -> 26 senales
#
# WWD: ejecutando 15 estrategias...
# WWD: breakout_volumen -> 355 senales
# WWD: cruce_medias -> 176 senales
# WWD: ema_9_21_cruce -> 224 senales
# WWD: ema_pullback -> sin senales
# WWD: gap_open_strategy -> 159 senales
# WWD: inside_bar_breakout -> sin senales
# WWD: ma_envelope_reversals -> 2378 senales
# WWD: macd_cruce -> 402 senales
# WWD: macd_hist_reversal -> 2644 senales
# WWD: mov_avg -> 331 senales
# WWD: rsi_divergencia -> 535 senales
# WWD: rsi_reversion -> 1086 senales
# WWD: sma_10_50_cruce -> 149 senales
# WWD: soporte_resistencia -> 838 senales
# WWD: volatilidad_contraria -> 15 senales
#
# WY: ejecutando 15 estrategias...
# WY: breakout_volumen -> 474 senales
# WY: cruce_medias -> 195 senales
# WY: ema_9_21_cruce -> 219 senales
# WY: ema_pullback -> sin senales
# WY: gap_open_strategy -> 86 senales
# WY: inside_bar_breakout -> sin senales
# WY: ma_envelope_reversals -> 2205 senales
# WY: macd_cruce -> 397 senales
# WY: macd_hist_reversal -> 2647 senales
# WY: mov_avg -> 305 senales
# WY: rsi_divergencia -> 590 senales
# WY: rsi_reversion -> 1240 senales
# WY: sma_10_50_cruce -> 135 senales
# WY: soporte_resistencia -> 989 senales
# WY: volatilidad_contraria -> 4 senales
#
# XEL: ejecutando 15 estrategias...
# XEL: breakout_volumen -> 360 senales
# XEL: cruce_medias -> 180 senales
# XEL: ema_9_21_cruce -> 224 senales
# XEL: ema_pullback -> sin senales
# XEL: gap_open_strategy -> 23 senales
# XEL: inside_bar_breakout -> sin senales
# XEL: ma_envelope_reversals -> 1112 senales
# XEL: macd_cruce -> 429 senales
# XEL: macd_hist_reversal -> 2690 senales
# XEL: mov_avg -> 327 senales
# XEL: rsi_divergencia -> 510 senales
# XEL: rsi_reversion -> 1127 senales
# XEL: sma_10_50_cruce -> 120 senales
# XEL: soporte_resistencia -> 879 senales
# XEL: volatilidad_contraria -> 24 senales
#
# XOM: ejecutando 15 estrategias...
# XOM: breakout_volumen -> 521 senales
# XOM: cruce_medias -> 173 senales
# XOM: ema_9_21_cruce -> 227 senales
# XOM: ema_pullback -> sin senales
# XOM: gap_open_strategy -> 70 senales
# XOM: inside_bar_breakout -> sin senales
# XOM: ma_envelope_reversals -> 1705 senales
# XOM: macd_cruce -> 427 senales
# XOM: macd_hist_reversal -> 2714 senales
# XOM: mov_avg -> 322 senales
# XOM: rsi_divergencia -> 529 senales
# XOM: rsi_reversion -> 1165 senales
# XOM: sma_10_50_cruce -> 139 senales
# XOM: soporte_resistencia -> 984 senales
# XOM: volatilidad_contraria -> 19 senales
#
# XYL: ejecutando 15 estrategias...
# XYL: breakout_volumen -> 271 senales
# XYL: cruce_medias -> 109 senales
# XYL: ema_9_21_cruce -> 141 senales
# XYL: ema_pullback -> sin senales
# XYL: gap_open_strategy -> 54 senales
# XYL: inside_bar_breakout -> sin senales
# XYL: ma_envelope_reversals -> 1344 senales
# XYL: macd_cruce -> 278 senales
# XYL: macd_hist_reversal -> 1815 senales
# XYL: mov_avg -> 193 senales
# XYL: rsi_divergencia -> 457 senales
# XYL: rsi_reversion -> 933 senales
# XYL: sma_10_50_cruce -> 81 senales
# XYL: soporte_resistencia -> 666 senales
# XYL: volatilidad_contraria -> 7 senales
#
# XPO: ejecutando 15 estrategias...
# XPO: breakout_volumen -> 372 senales
# XPO: cruce_medias -> 171 senales
# XPO: ema_9_21_cruce -> 221 senales
# XPO: ema_pullback -> sin senales
# XPO: gap_open_strategy -> 475 senales
# XPO: inside_bar_breakout -> sin senales
# XPO: ma_envelope_reversals -> 3138 senales
# XPO: macd_cruce -> 390 senales
# XPO: macd_hist_reversal -> 2605 senales
# XPO: mov_avg -> 314 senales
# XPO: rsi_divergencia -> 642 senales
# XPO: rsi_reversion -> 1292 senales
# XPO: sma_10_50_cruce -> 128 senales
# XPO: soporte_resistencia -> 750 senales
# XPO: volatilidad_contraria -> 44 senales
#
# XYZ: ejecutando 15 estrategias...
# XYZ: breakout_volumen -> 251 senales
# XYZ: cruce_medias -> 72 senales
# XYZ: ema_9_21_cruce -> 96 senales
# XYZ: ema_pullback -> sin senales
# XYZ: gap_open_strategy -> 208 senales
# XYZ: inside_bar_breakout -> sin senales
# XYZ: ma_envelope_reversals -> 1717 senales
# XYZ: macd_cruce -> 172 senales
# XYZ: macd_hist_reversal -> 1265 senales
# XYZ: mov_avg -> 134 senales
# XYZ: rsi_divergencia -> 354 senales
# XYZ: rsi_reversion -> 728 senales
# XYZ: sma_10_50_cruce -> 55 senales
# XYZ: soporte_resistencia -> 445 senales
# XYZ: volatilidad_contraria -> 4 senales
#
# YUMC: ejecutando 15 estrategias...
# YUMC: breakout_volumen -> 148 senales
# YUMC: cruce_medias -> 67 senales
# YUMC: ema_9_21_cruce -> 89 senales
# YUMC: ema_pullback -> sin senales
# YUMC: gap_open_strategy -> 100 senales
# YUMC: inside_bar_breakout -> sin senales
# YUMC: ma_envelope_reversals -> 1029 senales
# YUMC: macd_cruce -> 183 senales
# YUMC: macd_hist_reversal -> 1120 senales
# YUMC: mov_avg -> 161 senales
# YUMC: rsi_divergencia -> 244 senales
# YUMC: rsi_reversion -> 470 senales
# YUMC: sma_10_50_cruce -> 56 senales
# YUMC: soporte_resistencia -> 321 senales
# YUMC: volatilidad_contraria -> 6 senales
#
# YUM: ejecutando 15 estrategias...
# YUM: breakout_volumen -> 392 senales
# YUM: cruce_medias -> 199 senales
# YUM: ema_9_21_cruce -> 231 senales
# YUM: ema_pullback -> sin senales
# YUM: gap_open_strategy -> 72 senales
# YUM: inside_bar_breakout -> sin senales
# YUM: ma_envelope_reversals -> 1627 senales
# YUM: macd_cruce -> 405 senales
# YUM: macd_hist_reversal -> 2647 senales
# YUM: mov_avg -> 326 senales
# YUM: rsi_divergencia -> 597 senales
# YUM: rsi_reversion -> 1199 senales
# YUM: sma_10_50_cruce -> 154 senales
# YUM: soporte_resistencia -> 860 senales
# YUM: volatilidad_contraria -> 9 senales
#
# Z: ejecutando 15 estrategias...
# Z: breakout_volumen -> 202 senales
# Z: cruce_medias -> 81 senales
# Z: ema_9_21_cruce -> 95 senales
# Z: ema_pullback -> sin senales
# Z: gap_open_strategy -> 144 senales
# Z: inside_bar_breakout -> sin senales
# Z: ma_envelope_reversals -> 1677 senales
# Z: macd_cruce -> 187 senales
# Z: macd_hist_reversal -> 1314 senales
# Z: mov_avg -> 154 senales
# Z: rsi_divergencia -> 327 senales
# Z: rsi_reversion -> 680 senales
# Z: sma_10_50_cruce -> 60 senales
# Z: soporte_resistencia -> 448 senales
# Z: volatilidad_contraria -> 2 senales
#
# ZS: ejecutando 15 estrategias...
# ZS: breakout_volumen -> 176 senales
# ZS: cruce_medias -> 72 senales
# ZS: ema_9_21_cruce -> 82 senales
# ZS: ema_pullback -> sin senales
# ZS: gap_open_strategy -> 118 senales
# ZS: inside_bar_breakout -> sin senales
# ZS: ma_envelope_reversals -> 1289 senales
# ZS: macd_cruce -> 146 senales
# ZS: macd_hist_reversal -> 940 senales
# ZS: mov_avg -> 111 senales
# ZS: rsi_divergencia -> 288 senales
# ZS: rsi_reversion -> 549 senales
# ZS: sma_10_50_cruce -> 45 senales
# ZS: soporte_resistencia -> 332 senales
# ZS: volatilidad_contraria -> 10 senales
#
# ZM: ejecutando 15 estrategias...
# ZM: breakout_volumen -> 141 senales
# ZM: cruce_medias -> 49 senales
# ZM: ema_9_21_cruce -> 57 senales
# ZM: ema_pullback -> sin senales
# ZM: gap_open_strategy -> 110 senales
# ZM: inside_bar_breakout -> sin senales
# ZM: ma_envelope_reversals -> 1010 senales
# ZM: macd_cruce -> 106 senales
# ZM: macd_hist_reversal -> 802 senales
# ZM: mov_avg -> 80 senales
# ZM: rsi_divergencia -> 204 senales
# ZM: rsi_reversion -> 410 senales
# ZM: sma_10_50_cruce -> 34 senales
# ZM: soporte_resistencia -> 282 senales
# ZM: volatilidad_contraria -> 4 senales
#
# ZG: ejecutando 15 estrategias...
# ZG: breakout_volumen -> 292 senales
# ZG: cruce_medias -> 107 senales
# ZG: ema_9_21_cruce -> 129 senales
# ZG: ema_pullback -> sin senales
# ZG: gap_open_strategy -> 199 senales
# ZG: inside_bar_breakout -> sin senales
# ZG: ma_envelope_reversals -> 2425 senales
# ZG: macd_cruce -> 259 senales
# ZG: macd_hist_reversal -> 1821 senales
# ZG: mov_avg -> 204 senales
# ZG: rsi_divergencia -> 458 senales
# ZG: rsi_reversion -> 974 senales
# ZG: sma_10_50_cruce -> 83 senales
# ZG: soporte_resistencia -> 648 senales
# ZG: volatilidad_contraria -> 4 senales
#
# ZBH: ejecutando 15 estrategias...
# ZBH: breakout_volumen -> 389 senales
# ZBH: cruce_medias -> 192 senales
# ZBH: ema_9_21_cruce -> 230 senales
# ZBH: ema_pullback -> sin senales
# ZBH: gap_open_strategy -> 99 senales
# ZBH: inside_bar_breakout -> sin senales
# ZBH: ma_envelope_reversals -> 1893 senales
# ZBH: macd_cruce -> 396 senales
# ZBH: macd_hist_reversal -> 2664 senales
# ZBH: mov_avg -> 309 senales
# ZBH: rsi_divergencia -> 691 senales
# ZBH: rsi_reversion -> 1342 senales
# ZBH: sma_10_50_cruce -> 142 senales
# ZBH: soporte_resistencia -> 840 senales
# ZBH: volatilidad_contraria -> 15 senales
#
# ZTS: ejecutando 15 estrategias...
# ZTS: breakout_volumen -> 250 senales
# ZTS: cruce_medias -> 107 senales
# ZTS: ema_9_21_cruce -> 141 senales
# ZTS: ema_pullback -> sin senales
# ZTS: gap_open_strategy -> 41 senales
# ZTS: inside_bar_breakout -> sin senales
# ZTS: ma_envelope_reversals -> 1064 senales
# ZTS: macd_cruce -> 253 senales
# ZTS: macd_hist_reversal -> 1627 senales
# ZTS: mov_avg -> 214 senales
# ZTS: rsi_divergencia -> 336 senales
# ZTS: rsi_reversion -> 725 senales
# ZTS: sma_10_50_cruce -> 77 senales
# ZTS: soporte_resistencia -> 550 senales
# ZTS: volatilidad_contraria -> 13 senales
#
# ZBRA: ejecutando 15 estrategias...
# ZBRA: breakout_volumen -> 415 senales
# ZBRA: cruce_medias -> 158 senales
# ZBRA: ema_9_21_cruce -> 218 senales
# ZBRA: ema_pullback -> sin senales
# ZBRA: gap_open_strategy -> 119 senales
# ZBRA: inside_bar_breakout -> sin senales
# ZBRA: ma_envelope_reversals -> 2540 senales
# ZBRA: macd_cruce -> 382 senales
# ZBRA: macd_hist_reversal -> 2637 senales
# ZBRA: mov_avg -> 311 senales
# ZBRA: rsi_divergencia -> 691 senales
# ZBRA: rsi_reversion -> 1386 senales
# ZBRA: sma_10_50_cruce -> 125 senales
# ZBRA: soporte_resistencia -> 970 senales
# ZBRA: volatilidad_contraria -> 25 senales
#
#
# Senales guardadas en: C:\Users\leant\OneDrive\Documentos\trading\Jupyter\reports\senales_heuristicas\senales_heuristicas_2025-05-27.csv
# Total senales: 5134161
#
# Duracion total: 60.57 segundos

# %%
import pandas as pd
from pathlib import Path
from datetime import date

# === Rutas
BASE_PATH = Path("..").resolve().parent
REPORTS_DIR = BASE_PATH / "reports" / "senales_heuristicas"
FECHA = date.today().isoformat()
ARCHIVO = REPORTS_DIR / f"senales_heuristicas_{FECHA}.csv"

# === Leer archivo
df = pd.read_csv(ARCHIVO)
df["fecha"] = pd.to_datetime(df["fecha"], errors="coerce")

print(f"Total de señales: {len(df)}")
display(df.head(5))

# === Verificación de estructura
print("\nColumnas:", list(df.columns))
print("Fechas:", df["fecha"].min().date(), "-", df["fecha"].max().date())
print("Estrategias únicas:", df["estrategia"].nunique())
print("Símbolos únicos:", df["simbolo"].nunique())


# === Verificación de estructura
print("\nColumnas:", list(df.columns))
print("Fechas:", df["fecha"].min().date(), "→", df["fecha"].max().date())
print("Estrategias únicas:", df["estrategia"].nunique())
print("Símbolos únicos:", df["simbolo"].nunique())

# === Métricas por estrategia
resumen_estrategia = (
    df.groupby("estrategia")["signal"]
    .value_counts()
    .unstack(fill_value=0)
    .assign(total=lambda d: d.sum(axis=1))
    .sort_values("total", ascending=False)
)

print("\nResumen por estrategia:")
display(resumen_estrategia.head(10))

# === Señales por símbolo
resumen_simbolo = (
    df.groupby("simbolo")["signal"]
    .value_counts()
    .unstack(fill_value=0)
    .assign(total=lambda d: d.sum(axis=1))
    .sort_values("total", ascending=False)
)

print("\nResumen por símbolo:")
display(resumen_simbolo.head(10))

# === Señales por día (actividad temporal)
actividad_diaria = df.groupby("fecha").size()
print("\nActividad por fecha:")
display(actividad_diaria.tail(10))

# === Señales por combinación estrategia + símbolo (top 10)
combinaciones_top = (
    df.groupby(["estrategia", "simbolo"]).size()
    .sort_values(ascending=False)
    .head(20)
    .reset_index(name="total")
)

print("\nTop combinaciones estrategia + símbolo:")
display(combinaciones_top)
# Out:
# Total de señales: 5134161
#        fecha simbolo        estrategia signal
# 0 2021-01-14    ABNB  breakout_volumen    buy
# 1 2021-01-27    ABNB  breakout_volumen    buy
# 2 2021-05-06    ABNB  breakout_volumen   sell
# 3 2021-05-10    ABNB  breakout_volumen   sell
# 4 2021-05-11    ABNB  breakout_volumen   sell
# Columnas: ['fecha', 'simbolo', 'estrategia', 'signal']
# Fechas: 1998-06-08 - 2025-05-23
# Estrategias únicas: 13
# Símbolos únicos: 673
#
# Columnas: ['fecha', 'simbolo', 'estrategia', 'signal']
# Fechas: 1998-06-08 → 2025-05-23
# Estrategias únicas: 13
# Símbolos únicos: 673
#
# Resumen por estrategia:
# signal                    buy    sell    total
# estrategia
# macd_hist_reversal     726648  711234  1437882
# ma_envelope_reversals  511443  683698  1195141
# rsi_reversion          257828  430796   688624
# soporte_resistencia    284861  200393   485254
# rsi_divergencia        127113  209020   336133
# breakout_volumen       123666   97680   221346
# macd_cruce             109232  109291   218523
# mov_avg                 85852   85733   171585
# ema_9_21_cruce          61379   61236   122615
# cruce_medias            48513   48377    96890
# Resumen por símbolo:
# signal    buy  sell  total
# simbolo
# AMD      5676  5729  11405
# FCX      5452  5763  11215
# EXAS     5347  5735  11082
# URI      4967  6044  11011
# INSM     5554  5408  10962
# THC      5347  5601  10948
# NVDA     4966  5966  10932
# MU       5246  5686  10932
# GME      5580  5349  10929
# UAL      5318  5609  10927
# Actividad por fecha:
# fecha
# 2025-05-12    2544
# 2025-05-13    2028
# 2025-05-14    1715
# 2025-05-15    1458
# 2025-05-16    1545
# 2025-05-19    1426
# 2025-05-20    1278
# 2025-05-21    1077
# 2025-05-22    1064
# 2025-05-23    1154
# dtype: int64
# Top combinaciones estrategia + símbolo:
#                estrategia simbolo  total
# 0   ma_envelope_reversals     AMD   3527
# 1   ma_envelope_reversals    INSM   3520
# 2   ma_envelope_reversals    EXAS   3509
# 3   ma_envelope_reversals    BLDR   3373
# 4   ma_envelope_reversals     THC   3359
# 5   ma_envelope_reversals     GME   3352
# 6   ma_envelope_reversals      MU   3328
# 7   ma_envelope_reversals     ATI   3310
# 8   ma_envelope_reversals    ALNY   3310
# 9   ma_envelope_reversals     UAL   3282
# 10  ma_envelope_reversals     FCX   3280
# 11  ma_envelope_reversals    AXON   3255
# 12  ma_envelope_reversals     URI   3253
# 13  ma_envelope_reversals    DXCM   3245
# 14  ma_envelope_reversals    NFLX   3240
# 15  ma_envelope_reversals    FSLR   3240
# 16  ma_envelope_reversals    EXEL   3217
# 17  ma_envelope_reversals    CIEN   3174
# 18  ma_envelope_reversals    NVDA   3173
# 19  ma_envelope_reversals    COHR   3169

# %%
import pandas as pd
from pathlib import Path
from datetime import date

# === Rutas
BASE_PATH = Path("..").resolve().parent
REPORTS_DIR = BASE_PATH / "reports" / "senales_heuristicas"
FECHA = date.today().isoformat()
ARCHIVO = REPORTS_DIR / f"senales_heuristicas_{FECHA}.csv"

# === Leer CSV
df = pd.read_csv(ARCHIVO)
df["fecha"] = pd.to_datetime(df["fecha"], errors="coerce")

# === Verificaciones clave
print(f"Total filas: {len(df)}")
print("Tipos de columnas:")
print(df.dtypes)

# === Verificar valores unicos
print("\nValores unicos en 'signal':", df["signal"].unique())
print("Valores unicos en 'fecha':", df['fecha'].nunique())
print("Fecha minima:", df["fecha"].min())
print("Fecha maxima:", df["fecha"].max())

# === Señales por tipo
conteo = df["signal"].value_counts()
print("\nConteo por tipo de señal:")
print(conteo)

# === Detectar valores vacíos
faltantes = df.isna().sum()
print("\nColumnas con valores nulos:")
print(faltantes[faltantes > 0])
# Out:
# Total filas: 5134161
# Tipos de columnas:
# fecha         datetime64[ns]
# simbolo               object
# estrategia            object
# signal                object
# dtype: object
#
# Valores unicos en 'signal': ['buy' 'sell']
# Valores unicos en 'fecha': 7155
# Fecha minima: 1998-06-08 00:00:00
# Fecha maxima: 2025-05-23 00:00:00
#
# Conteo por tipo de señal:
# sell    2710909
# buy     2423252
# Name: signal, dtype: int64
#
# Columnas con valores nulos:
# Series([], dtype: int64)

# %%
import pandas as pd
from pathlib import Path

# === Ruta al archivo Parquet a verificar
ARCHIVO = Path("..") / ".." / "data" / "historic" / "aapl.parquet"  # Cambia el nombre de archivo si lo necesitas

# === Cargar archivo
df = pd.read_parquet(ARCHIVO)

# === Diagnóstico de columnas e índice
print(f"Columnas disponibles: {list(df.columns)}")
print(f"Tipo de índice: {type(df.index)}")
print(f"¿Índice es datetime? -> {pd.api.types.is_datetime64_any_dtype(df.index)}")

# === Mostrar primeras filas
display(df.head(3))
# Out:
# Columnas disponibles: ['datetime', 'open', 'high', 'low', 'close', 'volume']
# Tipo de índice: <class 'pandas.core.indexes.range.RangeIndex'>
# ¿Índice es datetime? -> False
#     datetime     open     high      low    close      volume
# 0 2005-07-12  1.36536  1.37143  1.35393  1.36571   387038400
# 1 2005-07-13  1.36750  1.37500  1.35357  1.36964   684835200
# 2 2005-07-14  1.45679  1.50036  1.43679  1.45536  2096060400

# %%
import pandas as pd
from pathlib import Path
from datetime import date

# === Ruta del archivo generado
BASE_PATH = Path("..").resolve().parent
FECHA = date.today().isoformat()
ARCHIVO = BASE_PATH / "reports" / "senales_heuristicas" / f"senales_heuristicas_{FECHA}.csv"

# === Cargar archivo
df = pd.read_csv(ARCHIVO)
df["fecha"] = pd.to_datetime(df["fecha"], errors="coerce")

# === Filtrar solo registros con fecha valida
df_validas = df[df["fecha"].notna()]

# === Total simbolos con al menos una senal valida
simbolos_con_senales = df_validas["simbolo"].nunique()
simbolos_total = df["simbolo"].nunique()

print(f"Simbolos con senales validas: {simbolos_con_senales} / {simbolos_total}")

# === Rango de fechas por simbolo
rango_fechas = (
    df_validas.groupby("simbolo")["fecha"]
    .agg(["min", "max"])
    .reset_index()
    .sort_values("simbolo")
)

print("\nRango de fechas por simbolo:")
display(rango_fechas)
# Out:
# Simbolos con senales validas: 673 / 673
#
# Rango de fechas por simbolo:
#     simbolo        min        max
# 0         A 2005-07-14 2025-05-20
# 1      AAPL 2005-07-13 2025-05-23
# 2      ABBV 2013-01-03 2025-05-22
# 3      ABNB 2020-12-11 2025-05-23
# 4       ABT 2005-07-13 2025-05-23
# ..      ...        ...        ...
# 668    ZBRA 2005-07-13 2025-05-23
# 669      ZG 2011-07-21 2025-05-23
# 670      ZM 2019-04-22 2025-05-23
# 671      ZS 2018-03-19 2025-05-23
# 672     ZTS 2013-02-04 2025-05-20
#
# [673 rows x 3 columns]

# %%
import pandas as pd
from pathlib import Path
from datetime import date

# === Ruta del archivo generado
BASE_PATH = Path("..").resolve().parent
FECHA = date.today().isoformat()
ARCHIVO = BASE_PATH / "reports" / "senales_heuristicas" / f"senales_heuristicas_{FECHA}.csv"

# === Cargar archivo
df = pd.read_csv(ARCHIVO)
df["fecha"] = pd.to_datetime(df["fecha"], errors="coerce")

# === Filtrar registros con fecha valida
df_validas = df[df["fecha"].notna()]

# === Agrupar por estrategia
resumen = (
    df_validas.groupby("estrategia")
    .agg(
        total_signals=("signal", "count"),
        buy_signals=("signal", lambda x: (x == "buy").sum()),
        sell_signals=("signal", lambda x: (x == "sell").sum()),
        fecha_min=("fecha", "min"),
        fecha_max=("fecha", "max")
    )
    .reset_index()
    .sort_values("total_signals", ascending=False)
)

# === Mostrar resultado
print("Resumen por estrategia:")
display(resumen)
# Out:
# Resumen por estrategia:
#                estrategia  total_signals  buy_signals  sell_signals  \
# 6      macd_hist_reversal        1437882       726648        711234
# 4   ma_envelope_reversals        1195141       511443        683698
# 9           rsi_reversion         688624       257828        430796
# 11    soporte_resistencia         485254       284861        200393
# 8         rsi_divergencia         336133       127113        209020
# 0        breakout_volumen         221346       123666         97680
# 5              macd_cruce         218523       109232        109291
# 7                 mov_avg         171585        85852         85733
# 2          ema_9_21_cruce         122615        61379         61236
# 1            cruce_medias          96890        48513         48377
# 3       gap_open_strategy          75472        37846         37626
# 10        sma_10_50_cruce          71798        35973         35825
# 12  volatilidad_contraria          12898        12898             0
#
#     fecha_min  fecha_max
# 6  1998-06-08 2025-05-23
# 4  1998-07-07 2025-05-23
# 9  1998-08-05 2025-05-23
# 11 1998-07-22 2025-05-23
# 8  1998-08-06 2025-05-23
# 0  1998-08-03 2025-05-23
# 5  1998-06-08 2025-05-23
# 7  1998-07-21 2025-05-23
# 2  1998-06-08 2025-05-23
# 1  1998-06-08 2025-05-23
# 3  1998-09-17 2025-05-23
# 10 1998-10-12 2025-05-23
# 12 1999-12-27 2025-05-23

# %%
import pandas as pd
from pathlib import Path
from datetime import datetime

# === Rutas
BASE_PATH = Path("..").resolve().parent
FECHA_HORA = datetime.now().strftime("%Y-%m-%d_%H-%M")
ARCHIVO = BASE_PATH / "reports" / "senales_heuristicas" / f"senales_heuristicas_{datetime.today().date()}.csv"
LOG_FILE = BASE_PATH / "reports" / "senales_heuristicas" / f"diagnostico_senales_{FECHA_HORA}.txt"

# === Leer archivo
df = pd.read_csv(ARCHIVO)
df["fecha"] = pd.to_datetime(df["fecha"], errors="coerce")

# === Diagnostico
output = []

output.append(f"Verificacion del archivo: {ARCHIVO.name}")
output.append(f"Total filas: {len(df)}")

# Columnas necesarias
columnas_necesarias = {"fecha", "simbolo", "estrategia", "signal"}
columnas_presentes = set(df.columns)
faltantes = columnas_necesarias - columnas_presentes

output.append("\nColumnas requeridas: " + str(columnas_necesarias))
output.append("Columnas presentes : " + str(columnas_presentes))
if faltantes:
    output.append(f"❌ Faltan columnas: {faltantes}")
else:
    output.append("✅ Todas las columnas requeridas están presentes.")

# Tipos de datos
output.append("\nTipos de columnas:")
output.append(str(df.dtypes))

# Señales
output.append("\nValores únicos en 'signal': " + str(df["signal"].unique().tolist()))
conteo = df["signal"].value_counts()
output.append("\nConteo por tipo de señal:")
output.append(str(conteo))

# Rango de fechas
output.append("\nFechas:")
output.append("Fecha mínima: " + str(df["fecha"].min()))
output.append("Fecha máxima: " + str(df["fecha"].max()))

# Nulos
nulos = df.isna().sum()
nulos_presentes = nulos[nulos > 0]
output.append("\nColumnas con valores nulos:")
output.append(str(nulos_presentes if not nulos_presentes.empty else "Sin nulos"))

# Veredicto
if not faltantes and df["fecha"].notna().all() and df["signal"].isin(["buy", "sell"]).all():
    output.append("\n✅ El archivo de señales esta listo para backtesting.")
else:
    output.append("\n⚠️ El archivo de señales tiene problemas que deben resolverse antes del backtesting.")

# === Imprimir resumen en pantalla
print("\n".join(output))

# === Guardar log con marca de tiempo
with open(LOG_FILE, "w", encoding="utf-8") as f:
    f.write("\n".join(output))

print(f"\n📝 Diagnostico guardado en: {LOG_FILE}")
# Out:
# Verificacion del archivo: senales_heuristicas_2025-05-27.csv
# Total filas: 5134161
#
# Columnas requeridas: {'fecha', 'signal', 'estrategia', 'simbolo'}
# Columnas presentes : {'fecha', 'signal', 'estrategia', 'simbolo'}
# ✅ Todas las columnas requeridas están presentes.
#
# Tipos de columnas:
# fecha         datetime64[ns]
# simbolo               object
# estrategia            object
# signal                object
# dtype: object
#
# Valores únicos en 'signal': ['buy', 'sell']
#
# Conteo por tipo de señal:
# sell    2710909
# buy     2423252
# Name: signal, dtype: int64
#
# Fechas:
# Fecha mínima: 1998-06-08 00:00:00
# Fecha máxima: 2025-05-23 00:00:00
#
# Columnas con valores nulos:
# Sin nulos
#
# ✅ El archivo de señales esta listo para backtesting.
#
# 📝 Diagnostico guardado en: C:\Users\leant\OneDrive\Documentos\trading\Jupyter\reports\senales_heuristicas\diagnostico_senales_2025-05-27_12-57.txt
